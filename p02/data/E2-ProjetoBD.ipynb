# %% [markdown]
# # Projeto de Bases de Dados - Parte 2
#
# ### Docente Responsável
#
# Prof. FirstName Teste
#
# ### Grupo 19
# <dl>
#     <dt>11 horas (33.3%)</dt>
#     <dd>ist1107030 Gabriel dos Reis Fonseca Castelo Ferreira</dd>
#     <dt>11 horas (33.3%)</dt>
#     <dd>ist1106763 David Rocha Rodrigues</dd>
#     <dt>1 horas (33.3%)</dt>
#     <dd>ist1105882 Duarte Mendonça Gouveia</dd>
# <dl>

# %%
# %reload_ext sql
# %config SqlMagic.displaycon = 0
# %config SqlMagic.displaylimit = 100
# %sql postgresql+psycopg://postgres:postgres@postgres/postgres
# Out:
# Connecting to 'postgresql+psycopg://postgres:***@postgres/postgres'

# %% [markdown]
# ## 0. Carregamento da Base de Dados
#
# Crie a base de dados “Saude” no PostgreSQL e execute os comandos para criação das tabelas desta base de dados apresentados de seguida

# %%
# %%sql
# DROP TABLE IF EXISTS clinica CASCADE;
# DROP TABLE IF EXISTS enfermeiro CASCADE;
# DROP TABLE IF EXISTS medico CASCADE;
# DROP TABLE IF EXISTS trabalha CASCADE;
# DROP TABLE IF EXISTS paciente CASCADE;
# DROP TABLE IF EXISTS receita CASCADE;
# DROP TABLE IF EXISTS consulta CASCADE;
# DROP TABLE IF EXISTS observacao CASCADE;
#
# CREATE TABLE clinica(
# 	nome VARCHAR(80) PRIMARY KEY,
# 	telefone VARCHAR(15) UNIQUE NOT NULL CHECK (telefone ~ '^[0-9]+$'),
# 	morada VARCHAR(255) UNIQUE NOT NULL
# );
#
# CREATE TABLE enfermeiro(
# 	nif CHAR(9) PRIMARY KEY CHECK (nif ~ '^[0-9]+$'),
# 	nome VARCHAR(80) UNIQUE NOT NULL,
# 	telefone VARCHAR(15) NOT NULL CHECK (telefone ~ '^[0-9]+$'),
# 	morada VARCHAR(255) NOT NULL,
# 	nome_clinica VARCHAR(80) NOT NULL REFERENCES clinica (nome)
# );
#
# CREATE TABLE medico(
# 	nif CHAR(9) PRIMARY KEY CHECK (nif ~ '^[0-9]+$'),
# 	nome VARCHAR(80) UNIQUE NOT NULL,
# 	telefone VARCHAR(15) NOT NULL CHECK (telefone ~ '^[0-9]+$'),
# 	morada VARCHAR(255) NOT NULL,
# 	especialidade VARCHAR(80) NOT NULL
# );
#
# CREATE TABLE trabalha(
# nif CHAR(9) NOT NULL REFERENCES medico,
# nome VARCHAR(80) NOT NULL REFERENCES clinica,
# dia_da_semana SMALLINT,
# PRIMARY KEY (nif, dia_da_semana)
# );
#
# CREATE TABLE paciente(
# 	ssn CHAR(11) PRIMARY KEY CHECK (ssn ~ '^[0-9]+$'),
# nif CHAR(9) UNIQUE NOT NULL CHECK (nif ~ '^[0-9]+$'),
# 	nome VARCHAR(80) NOT NULL,
# 	telefone VARCHAR(15) NOT NULL CHECK (telefone ~ '^[0-9]+$'),
# 	morada VARCHAR(255) NOT NULL,
# 	data_nasc DATE NOT NULL
# );
#
# CREATE TABLE consulta(
# 	id SERIAL PRIMARY KEY,
# 	ssn CHAR(11) NOT NULL REFERENCES paciente,
# 	nif CHAR(9) NOT NULL REFERENCES medico,
# 	nome VARCHAR(80) NOT NULL REFERENCES clinica,
# 	data DATE NOT NULL,
# 	hora TIME NOT NULL,
# 	codigo_sns CHAR(12) UNIQUE CHECK (codigo_sns ~ '^[0-9]+$'),
# 	UNIQUE(ssn, data, hora),
# 	UNIQUE(nif, data, hora)
# );
#
# CREATE TABLE receita(
# 	codigo_sns CHAR(12) NOT NULL REFERENCES consulta (codigo_sns),
# 	medicamento VARCHAR(155) NOT NULL,
# 	quantidade SMALLINT NOT NULL CHECK (quantidade > 0),
# 	PRIMARY KEY (codigo_sns, medicamento)
# );
#
# CREATE TABLE observacao(
# 	id INTEGER NOT NULL REFERENCES consulta,
# 	parametro VARCHAR(155) NOT NULL,
# 	valor FLOAT,
# PRIMARY KEY (id, parametro)
# );
#
# -- For some reason the docker container is defaulting to Universal Time,
# -- to avoid confusion we will change to Portuguese time
# SET timezone TO 'Europe/Lisbon';
# Out:
# ++
# ||
# ++
# ++

# %% [markdown]
# ## 1. Restrições de Integridade
#
# Apresente o código para implementar as seguintes restrições de integridade, se necessário, com recurso a extensões procedimentais SQL (Stored Procedures e Triggers):

# %% [markdown]
# (RI-1) Os horários das consultas são à hora exata ou meia-hora no horário 8-13h e 14-19h

# %%
# %%sql
# ALTER TABLE consulta
# DROP CONSTRAINT IF EXISTS consulta_time_check;
#
# ALTER TABLE consulta ADD CONSTRAINT consulta_time_check CHECK (
#   (
#     (
#       EXTRACT(
#         HOUR
#         FROM
#           hora
#       ) BETWEEN 8 AND 12
#     )
#     OR (
#       EXTRACT(
#         HOUR
#         FROM
#           hora
#       ) BETWEEN 14 AND 18
#     )
#     AND EXTRACT(
#       MINUTE
#       FROM
#         hora
#     ) IN (0, 30)
#   )
# );
# Out:
# ++
# ||
# ++
# ++

# %% [markdown]
# (RI-2) Um médico não se pode consultar a si próprio, embora possa ser paciente de outros médicos no sistema

# %%
# %%sql
# CREATE OR REPLACE FUNCTION consulta_medico() RETURNS TRIGGER AS $$
#     BEGIN
#         IF EXISTS (
#             SELECT * FROM paciente p
#             WHERE NEW.ssn = p.ssn AND NEW.nif = p.nif
#         ) THEN
#             RAISE EXCEPTION 'Um médico não se pode consultar a si próprio.';
#         END IF;
#         RETURN NEW;
#     END;
# $$ LANGUAGE plpgsql;
# CREATE OR REPLACE TRIGGER consulta_medico_trigger BEFORE INSERT ON consulta
#     FOR EACH ROW EXECUTE FUNCTION consulta_medico();
# Out:
# ++
# ||
# ++
# ++

# %% [markdown]
# (RI-3) Um médico só pode dar consultas na clínica em que trabalha no dia da semana correspondente à data da consulta

# %%
# %%sql
# CREATE OR REPLACE FUNCTION consulta_clinica() RETURNS TRIGGER AS $$
#     BEGIN
#         IF NOT EXISTS (
#             SELECT * FROM trabalha t
#             WHERE NEW.nif = t.nif AND NEW.nome = t.nome AND EXTRACT(ISODOW FROM NEW.data) = t.dia_da_semana
#         ) THEN
#             RAISE EXCEPTION 'Um médico só pode dar consultas na clínica em que trabalha nesse dia.';
#         END IF;
#         RETURN NEW;
#     END;
# $$ LANGUAGE plpgsql;
# CREATE OR REPLACE TRIGGER consulta_clinica_trigger BEFORE INSERT ON consulta
#     FOR EACH ROW EXECUTE FUNCTION consulta_clinica();
# Out:
# ++
# ||
# ++
# ++

# %% [markdown]
# ## 2. Preenchimento da Base de Dados
#
# Preencha todas as tabelas da base de dados de forma consistente (após execução do ponto anterior) com os seguintes requisitos adicionais de cobertura:
# - 5 clínicas, de pelo menos 3 localidades diferentes do distrito de Lisboa
# - 5-6 enfermeiros por clínica
# - 20 médicos de especialidade ‘clínica geral’ e 40 outros distribuídos como entender por até 5 outras especialidades médicas (incluindo pelo menos, ‘ortopedia’ e ‘cardiologia’). Cada médico deve trabalhar em pelo menos duas clínicas, e em cada clínica a cada dia da semana (incluindo fins de semana), devem estar pelo menos 8 médicos
# - Cerca de 5.000 pacientes
# - Um número mínimo de consultas em 2023 e 2024 tais que cada paciente tem pelo menos uma consulta, e em cada dia há pelo menos 20 consultas por clínica, e pelo menos 2 consultas por médico
# - ~80% das consultas tem receita médica associada, e as receitas têm 1 a 6 medicamentos em quantidades entre 1 e 3
# - Todas as consultas têm 1 a 5 observações de sintomas (com parâmetro mas sem valor) e 0 a 3 observações métricas (com parâmetro e valor). Deve haver ~50 parâmetros diferentes para os sintomas (sem valor) e ~20 parâmetros diferentes para as observações métricas (com valor) e os dois conjuntos devem ser disjuntos.
# - Todas as moradas são nacionais e seguem o formato Português, terminando com código postal: XXXX-XXX e de seguida a localidade.
# Deve ainda garantir que todas as consultas necessárias para a realização dos pontos seguintes do projeto produzem um resultado não vazio.
#
# O código para preenchimento da base de dados deve ser compilado num ficheiro "populate.sql", anexado ao relatório, que contém com comandos INSERT ou alternativamente comandos COPY que populam as tabelas a partir de ficheiros de texto, também eles anexados ao relatório.

# %% [markdown]
# Para preencher a base de dados correr o comando no terminal
# ```bash
# psql -h postgres -U postgres
# \i ~/data/populate.sql
# ```

# %% [markdown]
# ## 3. Desenvolvimento de Aplicação
#
# Crie um protótipo de RESTful web service para gestão de consultas por acesso programático à base de dados ‘Saude’ através de uma API que devolve respostas em JSON, implementando os seguintes endpoints REST:
#
# |Endpoint|Descrição|
# |--------|---------|
# |/|Lista todas as clínicas (nome e morada).|
# |/c/\<clinica>/|Lista todas as especialidades oferecidas na \<clinica>.|
# |/c/\<clinica>/\<especialidade>/|Lista todos os médicos (nome) da \<especialidade> que trabalham na <clínica> e os primeiros três horários disponíveis para consulta de cada um deles (data e hora).|
# |/a/\<clinica>/registar/|Registra uma marcação de consulta na \<clinica> na base de dados (populando a respectiva tabela). Recebe como argumentos um paciente, um médico, e uma data e hora (posteriores ao momento de agendamento).|
# |/a/\<clinica>/cancelar/|Cancela uma marcação de consulta que ainda não se realizou na \<clinica> (o seu horário é posterior ao momento do cancelamento), removendo a entrada da respectiva tabela na base de dados. Recebe como argumentos um paciente, um médico, e uma data e hora.|

# %% [markdown]
# %%sql
# DROP TABLE distinct_horas;
# CREATE TABLE distinct_horas AS
# SELECT DISTINCT hora
# FROM consulta ORDER BY hora;

# %%
### Explicação da arquitetura da aplicação web, incluindo a descrição dos vários ficheiros na pasta app/arquivos e a relação entre eles

A nossa pasta app está dividida em 4 elementos. Uma primeira pasta saude que contém a coleção de todas as requests da app realizadas no 
programa Bruno. De seguida temos o ficheiro "app.py" de código da nossa app onde desenvolvemos os vários comandos solicitados no enunciado. Por último, 
temos ainda os dois ficheiros "Dockerfile.development" e "requirements.txt" que nos perimitem correr a app no Docker.

# %% [markdown]
# ## 4. Vistas
#
# Crie uma vista materializada que detalhe as informações mais importantes sobre as consultas dos pacientes, combinando a informação de várias tabelas da base de dados. A vista deve ter o seguinte esquema:
#
# ### *historial_paciente(id, ssn, nif, nome, data, ano, mes, dia_do_mes, localidade, especialidade, tipo, chave, valor)*
#
# em que:
# - *id, ssn, nif, nome* e *data*: correspondem ao atributos homónimos da tabela **consulta**
# - *ano, mes, dia_do_mes* e *dia_da_semana*: são derivados do atributo *data* da tabela **consulta**
# - *localidade*: é derivado do atributo *morada* da tabela **clinica**
# - *especialidade*: corresponde ao atributo homónimo da tabela **medico**
# - *tipo*: toma os valores ‘observacao’ ou ‘receita’ consoante o preenchimento dos campos seguintes
# - *chave*: corresponde ao atributo *parametro* da tabela **observacao** ou ao atributo *medicamento* da tabela **receita**
# - *valor*: corresponde ao atributo *valor* da tabela **observacao** ou ao atributo *quantidade* da tabela **receita**

# %%
# %%sql
# DROP MATERIALIZED VIEW IF EXISTS historial_paciente;
#
# CREATE MATERIALIZED VIEW historial_paciente AS
# SELECT
#   consulta.id,
#   consulta.ssn,
#   consulta.nif,
#   consulta.nome,
#   consulta.data,
#   EXTRACT(
#     YEAR
#     FROM
#       consulta.data
#   ) AS ano,
#   EXTRACT(
#     MONTH
#     FROM
#       consulta.data
#   ) AS mes,
#   EXTRACT(
#     DAY
#     FROM
#       consulta.data
#   ) AS dia_do_mes,
#   regexp_replace (clinica.morada, '.*\d{4}-\d{3} ', '') AS localidade,
#   medico.especialidade,
#   'observacao' AS tipo,
#   observacao.parametro AS chave,
#   observacao.valor AS valor
# FROM
#   consulta
#   JOIN medico ON consulta.nif = medico.nif
#   JOIN clinica ON consulta.nome = clinica.nome
#   JOIN observacao ON consulta.id = observacao.id
# UNION
# SELECT
#   consulta.id,
#   consulta.ssn,
#   consulta.nif,
#   consulta.nome,
#   consulta.data,
#   EXTRACT(
#     YEAR
#     FROM
#       consulta.data
#   ) AS ano,
#   EXTRACT(
#     MONTH
#     FROM
#       consulta.data
#   ) AS mes,
#   EXTRACT(
#     DAY
#     FROM
#       consulta.data
#   ) AS dia_do_mes,
#   regexp_replace (clinica.morada, '.*\d{4}-\d{3} ', '') AS localidade,
#   medico.especialidade,
#   'receita' AS tipo,
#   receita.medicamento AS chave,
#   receita.quantidade AS valor
# FROM
#   consulta
#   JOIN medico ON consulta.nif = medico.nif
#   JOIN clinica ON consulta.nome = clinica.nome
#   JOIN receita ON consulta.codigo_sns = receita.codigo_sns;
# Out:
# 1121107 rows affected.
# ++
# ||
# ++
# ++

# %% [markdown]
# ## 5. Análise de Dados (SQL e OLAP)
#
# Usando a vista desenvolvida no ponto anterior, complementada com outras tabelas da base de dados ‘Saude’ quando necessário, apresente a consulta SQL mais sucinta para cada um dos seguintes objetivos analíticos. Pode usar as instruções ROLLUP, CUBE, GROUPING SETS ou as cláusulas UNION of GROUP BY para os objetivos em que lhe parecer adequado.

# %% [markdown]
# 1. Determinar que paciente(s) tiveram menos progresso no tratamento das suas doenças do foro ortopédico para atribuição de uma consulta gratuita. Considera-se que o indicador de falta de progresso é o intervalo temporal máximo entre duas observações do mesmo sintoma (i.e. registos de tipo ‘observacao’ com a mesma chave e com valor NULL) em consultas de ortopedia.

# %%
# %%sql
# SELECT
#   p.nome,
#   ssn,
#   MAX(dias_sem_melhoria) AS dias_sem_melhoria
# FROM
#   (
#     SELECT
#       h.ssn,
#       h.chave,
#       (MAX(h.data) - MIN(h.data)) AS dias_sem_melhoria
#     FROM
#       historial_paciente h
#     WHERE
#       h.tipo = 'observacao'
#       AND h.valor IS NULL
#       AND h.especialidade = 'ortopedia'
#     GROUP BY
#       h.ssn,
#       h.chave
#   )
#   JOIN paciente p USING (ssn)
# GROUP BY
#   ssn,
#   p.nome
# ORDER BY
#   dias_sem_melhoria DESC
# LIMIT
#   10;
# Out:
# 10 rows affected.
# +---------------------+-------------+-------------------+
# |         nome        |     ssn     | dias_sem_melhoria |
# +---------------------+-------------+-------------------+
# |    Priscila Vidal   | 12391152709 |        726        |
# |     Neusa Macedo    | 11522403520 |        720        |
# |    Beatriz Klein    | 12438510339 |        720        |
# |   Catarina Vieira   | 12382704452 |        719        |
# |    Patrícia Ramos   | 12494101774 |        707        |
# |   Cátia Gonçalves   | 12332138012 |        702        |
# |  Washington Antunes | 12328191599 |        701        |
# |    Zoraide Santos   | 12367295145 |        699        |
# |    Osvaldo Ulhoa    | 11566412635 |        694        |
# | Matheus Vasconcelos | 12432192274 |        692        |
# +---------------------+-------------+-------------------+

# %% [markdown]
# 2. Determinar que medicamentos estão a ser usados para tratar doenças crónicas do foro cardiológico. Considera-se que qualificam quaisquer medicamentos receitados ao mesmo paciente (qualquer que ele seja) pelo menos uma vez por mês durante os últimos doze meses, em consultas de cardiologia.

# %%
# %%sql
# SELECT DISTINCT
#   h.chave AS medicamento
# FROM
#   historial_paciente h
# WHERE
#   h.tipo = 'receita'
#   AND especialidade = 'cardiologia'
#   AND h.data BETWEEN CURRENT_DATE - INTERVAL '1 year' AND CURRENT_DATE
# GROUP BY
#   h.ssn,
#   h.chave
# HAVING
#   COUNT(DISTINCT h.mes) = 12;
# Out:
# 4 rows affected.
# +-------------+
# | medicamento |
# +-------------+
# |  Ethinamate |
# |  Fonazepam  |
# |  Gestrinone |
# |  Methadone  |
# +-------------+

# %% [markdown]
# 3. Explorar as quantidades totais receitadas de cada medicamento em 2023, globalmente, e com drill down nas dimensões espaço (localidade > clinica), tempo (mes > dia_do_mes), e médico  (especialidade > nome \[do médico]), separadamente.

# %%
# %%sql
# WITH
#   medicamentos AS (
#     SELECT mes, dia_do_mes,
#       localidade, h.nome AS clinica,
#       h.especialidade, m.nome AS nome_medico,
#       chave AS medicamento, valor AS qtd
#     FROM historial_paciente h
#       JOIN medico m USING (nif)
#     WHERE tipo = 'receita'
#       AND ano = 2023
#   )
# SELECT
#   medicamento, localidade, clinica, especialidade, nome_medico, mes, dia_do_mes,
#   SUM(qtd)
# FROM
#   medicamentos
# GROUP BY
#   GROUPING SETS (
#     (medicamento),
#     (medicamento, localidade),
#     (medicamento, localidade, clinica),
#     (medicamento, mes),
#     (medicamento, mes, dia_do_mes),
#     (medicamento, especialidade),
#     (medicamento, especialidade, nome_medico)
#   )
# ORDER BY
#   medicamento, localidade, clinica, especialidade, nome_medico DESC, mes, dia_do_mes
# ;
# Out:
# 19540 rows affected.
# +-------------+--------------+-------------------------------+---------------+-----------------+------+------------+--------+
# | medicamento |  localidade  |            clinica            | especialidade |   nome_medico   | mes  | dia_do_mes |  sum   |
# +-------------+--------------+-------------------------------+---------------+-----------------+------+------------+--------+
# |  Alfentanil |  Carcavelos  |        Clinica Sabeanas       |      None     |       None      | None |    None    | 291.0  |
# |  Alfentanil |  Carcavelos  |              None             |      None     |       None      | None |    None    | 291.0  |
# |  Alfentanil |  Carregado   |        Clinica Dentejo        |      None     |       None      | None |    None    | 115.0  |
# |  Alfentanil |  Carregado   |              None             |      None     |       None      | None |    None    | 115.0  |
# |  Alfentanil |    Lisboa    |    Centro Clinico dos Anjos   |      None     |       None      | None |    None    | 107.0  |
# |  Alfentanil |    Lisboa    |     Clinica Sorriso Famoso    |      None     |       None      | None |    None    | 465.0  |
# |  Alfentanil |    Lisboa    |              None             |      None     |       None      | None |    None    | 572.0  |
# |  Alfentanil | Rio de Mouro | Clinica Joaquim Chaves Sintra |      None     |       None      | None |    None    | 441.0  |
# |  Alfentanil | Rio de Mouro |              None             |      None     |       None      | None |    None    | 441.0  |
# |  Alfentanil |     None     |              None             |   neurologia  |       None      | None |    None    | 1419.0 |
# |  Alfentanil |     None     |              None             |   neurologia  | Gabriela Cabral | None |    None    | 728.0  |
# |  Alfentanil |     None     |              None             |   neurologia  |  Erica Tavares  | None |    None    | 691.0  |
# |  Alfentanil |     None     |              None             |      None     |       None      |  1   |     2      |  3.0   |
# |  Alfentanil |     None     |              None             |      None     |       None      |  1   |     3      |  5.0   |
# |  Alfentanil |     None     |              None             |      None     |       None      |  1   |     4      |  4.0   |
# |  Alfentanil |     None     |              None             |      None     |       None      |  1   |     5      |  5.0   |
# |  Alfentanil |     None     |              None             |      None     |       None      |  1   |     7      |  3.0   |
# |  Alfentanil |     None     |              None             |      None     |       None      |  1   |     8      |  6.0   |
# |  Alfentanil |     None     |              None             |      None     |       None      |  1   |     9      |  3.0   |
# |  Alfentanil |     None     |              None             |      None     |       None      |  1   |     10     |  3.0   |
# |  Alfentanil |     None     |              None             |      None     |       None      |  1   |     11     |  5.0   |
# |  Alfentanil |     None     |              None             |      None     |       None      |  1   |     12     |  6.0   |
# |  Alfentanil |     None     |              None             |      None     |       None      |  1   |     13     |  4.0   |
# |  Alfentanil |     None     |              None             |      None     |       None      |  1   |     14     |  4.0   |
# |  Alfentanil |     None     |              None             |      None     |       None      |  1   |     15     |  3.0   |
# |  Alfentanil |     None     |              None             |      None     |       None      |  1   |     16     |  4.0   |
# |  Alfentanil |     None     |              None             |      None     |       None      |  1   |     17     |  13.0  |
# |  Alfentanil |     None     |              None             |      None     |       None      |  1   |     18     |  2.0   |
# |  Alfentanil |     None     |              None             |      None     |       None      |  1   |     19     |  4.0   |
# |  Alfentanil |     None     |              None             |      None     |       None      |  1   |     20     |  7.0   |
# |  Alfentanil |     None     |              None             |      None     |       None      |  1   |     21     |  4.0   |
# |  Alfentanil |     None     |              None             |      None     |       None      |  1   |     22     |  6.0   |
# |  Alfentanil |     None     |              None             |      None     |       None      |  1   |     23     |  3.0   |
# |  Alfentanil |     None     |              None             |      None     |       None      |  1   |     24     |  10.0  |
# |  Alfentanil |     None     |              None             |      None     |       None      |  1   |     25     |  3.0   |
# |  Alfentanil |     None     |              None             |      None     |       None      |  1   |     26     |  1.0   |
# |  Alfentanil |     None     |              None             |      None     |       None      |  1   |     27     |  3.0   |
# |  Alfentanil |     None     |              None             |      None     |       None      |  1   |     29     |  5.0   |
# |  Alfentanil |     None     |              None             |      None     |       None      |  1   |     30     |  8.0   |
# |  Alfentanil |     None     |              None             |      None     |       None      |  1   |     31     |  5.0   |
# |  Alfentanil |     None     |              None             |      None     |       None      |  1   |    None    | 132.0  |
# |  Alfentanil |     None     |              None             |      None     |       None      |  2   |     1      |  3.0   |
# |  Alfentanil |     None     |              None             |      None     |       None      |  2   |     2      |  6.0   |
# |  Alfentanil |     None     |              None             |      None     |       None      |  2   |     3      |  4.0   |
# |  Alfentanil |     None     |              None             |      None     |       None      |  2   |     4      |  5.0   |
# |  Alfentanil |     None     |              None             |      None     |       None      |  2   |     5      |  1.0   |
# |  Alfentanil |     None     |              None             |      None     |       None      |  2   |     6      |  1.0   |
# |  Alfentanil |     None     |              None             |      None     |       None      |  2   |     8      |  1.0   |
# |  Alfentanil |     None     |              None             |      None     |       None      |  2   |     9      |  6.0   |
# |  Alfentanil |     None     |              None             |      None     |       None      |  2   |     10     |  4.0   |
# |  Alfentanil |     None     |              None             |      None     |       None      |  2   |     11     |  2.0   |
# |  Alfentanil |     None     |              None             |      None     |       None      |  2   |     12     |  2.0   |
# |  Alfentanil |     None     |              None             |      None     |       None      |  2   |     13     |  2.0   |
# |  Alfentanil |     None     |              None             |      None     |       None      |  2   |     14     |  4.0   |
# |  Alfentanil |     None     |              None             |      None     |       None      |  2   |     15     |  10.0  |
# |  Alfentanil |     None     |              None             |      None     |       None      |  2   |     17     |  2.0   |
# |  Alfentanil |     None     |              None             |      None     |       None      |  2   |     18     |  5.0   |
# |  Alfentanil |     None     |              None             |      None     |       None      |  2   |     19     |  6.0   |
# |  Alfentanil |     None     |              None             |      None     |       None      |  2   |     20     |  5.0   |
# |  Alfentanil |     None     |              None             |      None     |       None      |  2   |     21     |  1.0   |
# |  Alfentanil |     None     |              None             |      None     |       None      |  2   |     22     |  4.0   |
# |  Alfentanil |     None     |              None             |      None     |       None      |  2   |     23     |  5.0   |
# |  Alfentanil |     None     |              None             |      None     |       None      |  2   |     25     |  4.0   |
# |  Alfentanil |     None     |              None             |      None     |       None      |  2   |     26     |  4.0   |
# |  Alfentanil |     None     |              None             |      None     |       None      |  2   |     27     |  5.0   |
# |  Alfentanil |     None     |              None             |      None     |       None      |  2   |     28     |  6.0   |
# |  Alfentanil |     None     |              None             |      None     |       None      |  2   |    None    |  98.0  |
# |  Alfentanil |     None     |              None             |      None     |       None      |  3   |     1      |  1.0   |
# |  Alfentanil |     None     |              None             |      None     |       None      |  3   |     2      |  6.0   |
# |  Alfentanil |     None     |              None             |      None     |       None      |  3   |     3      |  7.0   |
# |  Alfentanil |     None     |              None             |      None     |       None      |  3   |     4      |  6.0   |
# |  Alfentanil |     None     |              None             |      None     |       None      |  3   |     5      |  5.0   |
# |  Alfentanil |     None     |              None             |      None     |       None      |  3   |     6      |  6.0   |
# |  Alfentanil |     None     |              None             |      None     |       None      |  3   |     7      |  3.0   |
# |  Alfentanil |     None     |              None             |      None     |       None      |  3   |     8      |  2.0   |
# |  Alfentanil |     None     |              None             |      None     |       None      |  3   |     9      |  2.0   |
# |  Alfentanil |     None     |              None             |      None     |       None      |  3   |     10     |  2.0   |
# |  Alfentanil |     None     |              None             |      None     |       None      |  3   |     11     |  4.0   |
# |  Alfentanil |     None     |              None             |      None     |       None      |  3   |     12     |  5.0   |
# |  Alfentanil |     None     |              None             |      None     |       None      |  3   |     13     |  3.0   |
# |  Alfentanil |     None     |              None             |      None     |       None      |  3   |     14     |  7.0   |
# |  Alfentanil |     None     |              None             |      None     |       None      |  3   |     15     |  7.0   |
# |  Alfentanil |     None     |              None             |      None     |       None      |  3   |     17     |  5.0   |
# |  Alfentanil |     None     |              None             |      None     |       None      |  3   |     18     |  3.0   |
# |  Alfentanil |     None     |              None             |      None     |       None      |  3   |     19     |  7.0   |
# |  Alfentanil |     None     |              None             |      None     |       None      |  3   |     20     |  2.0   |
# |  Alfentanil |     None     |              None             |      None     |       None      |  3   |     21     |  6.0   |
# |  Alfentanil |     None     |              None             |      None     |       None      |  3   |     22     |  6.0   |
# |  Alfentanil |     None     |              None             |      None     |       None      |  3   |     24     |  4.0   |
# |  Alfentanil |     None     |              None             |      None     |       None      |  3   |     25     |  1.0   |
# |  Alfentanil |     None     |              None             |      None     |       None      |  3   |     27     |  1.0   |
# |  Alfentanil |     None     |              None             |      None     |       None      |  3   |     28     |  3.0   |
# |  Alfentanil |     None     |              None             |      None     |       None      |  3   |     29     |  7.0   |
# |  Alfentanil |     None     |              None             |      None     |       None      |  3   |     30     |  3.0   |
# |  Alfentanil |     None     |              None             |      None     |       None      |  3   |     31     |  1.0   |
# |  Alfentanil |     None     |              None             |      None     |       None      |  3   |    None    | 115.0  |
# |  Alfentanil |     None     |              None             |      None     |       None      |  4   |     1      |  3.0   |
# |  Alfentanil |     None     |              None             |      None     |       None      |  4   |     3      |  5.0   |
# |  Alfentanil |     None     |              None             |      None     |       None      |  4   |     4      |  5.0   |
# |  Alfentanil |     None     |              None             |      None     |       None      |  4   |     5      |  3.0   |
# +-------------+--------------+-------------------------------+---------------+-----------------+------+------------+--------+
# Truncated to displaylimit of 100.

# %% [markdown]
# 4. Determinar se há enviesamento na medição de algum parâmetros entre clínicas, especialidades médicas ou médicos, sendo para isso necessário listar o valor médio e desvio padrão de todos os parâmetros de observações métricas (i.e. com valor não NULL) com drill down na dimensão médico (globalmente > especialidade > nome \[do médico]) e drill down adicional (sobre o anterior) por clínica.

# %%
# %%sql
# WITH
#   medicamentos AS (
#     SELECT
#       h.especialidade, m.nome AS nome_medico,
#       h.nome AS clinica,
#       chave AS parametro,
#       valor
#     FROM
#       historial_paciente h
#       JOIN medico m USING (nif)
#     WHERE
#       tipo = 'observacao' AND valor IS NOT NULL
#   )
# SELECT parametro, especialidade, nome_medico, clinica, AVG(valor), STDDEV_POP(valor)
# FROM medicamentos
# GROUP BY ROLLUP (parametro, especialidade, nome_medico, clinica)
# ORDER BY parametro, especialidade, nome_medico DESC, clinica DESC;
# Out:
# 4721 rows affected.
# +---------------------------------+---------------+----------------------+-------------------------------+-------------------+--------------------+
# |            parametro            | especialidade |     nome_medico      |            clinica            |        avg        |     stddev_pop     |
# +---------------------------------+---------------+----------------------+-------------------------------+-------------------+--------------------+
# | Batimentos cardíacos por minuto |  cardiologia  |         None         |              None             | 80.04070402025977 | 6.6989612891371575 |
# | Batimentos cardíacos por minuto |  cardiologia  |  Valéria Guimarães   |              None             | 80.31327433628317 | 6.294647120853325  |
# | Batimentos cardíacos por minuto |  cardiologia  |  Valéria Guimarães   |        Clinica Sabeanas       | 79.52868421052635 | 5.6017068221506925 |
# | Batimentos cardíacos por minuto |  cardiologia  |  Valéria Guimarães   | Clinica Joaquim Chaves Sintra | 80.93958823529415 | 6.014966368873988  |
# | Batimentos cardíacos por minuto |  cardiologia  |  Valéria Guimarães   |        Clinica Dentejo        | 80.36588477366253 | 6.820942299037956  |
# | Batimentos cardíacos por minuto |  cardiologia  | Ubirajara Rodrigues  |              None             |  79.9923642172525 | 6.478484975163261  |
# | Batimentos cardíacos por minuto |  cardiologia  | Ubirajara Rodrigues  |        Clinica Sabeanas       | 80.18231460674166 | 6.554752168534691  |
# | Batimentos cardíacos por minuto |  cardiologia  | Ubirajara Rodrigues  |        Clinica Dentejo        |  79.5253591160221 | 6.262597955986678  |
# | Batimentos cardíacos por minuto |  cardiologia  |     Silvia Zanin     |              None             | 80.13731012658222 | 6.775798171864834  |
# | Batimentos cardíacos por minuto |  cardiologia  |     Silvia Zanin     |     Clinica Sorriso Famoso    | 80.62873684210528 | 6.429215019957973  |
# | Batimentos cardíacos por minuto |  cardiologia  |     Silvia Zanin     |        Clinica Sabeanas       | 80.31858267716541 | 6.947260404292774  |
# | Batimentos cardíacos por minuto |  cardiologia  |     Silvia Zanin     |    Centro Clinico dos Anjos   | 79.39574468085108 | 6.8205091201622485 |
# | Batimentos cardíacos por minuto |  cardiologia  |     Silvia Neves     |              None             | 79.82495145631069 | 6.855828036938877  |
# | Batimentos cardíacos por minuto |  cardiologia  |     Silvia Neves     |        Clinica Sabeanas       |  79.894064171123  | 7.580224592509608  |
# | Batimentos cardíacos por minuto |  cardiologia  |     Silvia Neves     | Clinica Joaquim Chaves Sintra | 79.91581395348838 | 6.258167772788092  |
# | Batimentos cardíacos por minuto |  cardiologia  |     Silvia Neves     |        Clinica Dentejo        | 79.85795180722894 | 6.428591398679141  |
# | Batimentos cardíacos por minuto |  cardiologia  |     Silvia Neves     |    Centro Clinico dos Anjos   | 79.67849162011179 |  6.71380412889851  |
# | Batimentos cardíacos por minuto |  cardiologia  |    Quintino Ulhoa    |              None             | 80.04092621664041 | 6.523084374310026  |
# | Batimentos cardíacos por minuto |  cardiologia  |    Quintino Ulhoa    |     Clinica Sorriso Famoso    | 79.66448087431695 | 6.319280119858652  |
# | Batimentos cardíacos por minuto |  cardiologia  |    Quintino Ulhoa    |        Clinica Sabeanas       | 80.46611111111102 | 6.304249130448879  |
# | Batimentos cardíacos por minuto |  cardiologia  |    Quintino Ulhoa    | Clinica Joaquim Chaves Sintra | 79.85153465346538 | 6.930648257457674  |
# | Batimentos cardíacos por minuto |  cardiologia  |    Quintino Koch     |              None             | 80.40907153729071 | 6.488391616894146  |
# | Batimentos cardíacos por minuto |  cardiologia  |    Quintino Koch     |     Clinica Sorriso Famoso    | 80.26410810810815 |  7.03348765043724  |
# | Batimentos cardíacos por minuto |  cardiologia  |    Quintino Koch     |        Clinica Dentejo        | 80.46588983050857 | 6.260895490566416  |
# | Batimentos cardíacos por minuto |  cardiologia  |   Otávio Monteiro    |              None             | 79.88044546850992 | 6.597107937186659  |
# | Batimentos cardíacos por minuto |  cardiologia  |   Otávio Monteiro    |     Clinica Sorriso Famoso    | 79.11400000000003 | 6.3947202329064305 |
# | Batimentos cardíacos por minuto |  cardiologia  |   Otávio Monteiro    |        Clinica Sabeanas       | 79.83913580246916 | 6.497442269330762  |
# | Batimentos cardíacos por minuto |  cardiologia  |   Otávio Monteiro    | Clinica Joaquim Chaves Sintra | 80.10744791666663 | 6.676713828626374  |
# | Batimentos cardíacos por minuto |  cardiologia  |      Oscar Reis      |              None             | 80.26575193798459 | 6.910491020181971  |
# | Batimentos cardíacos por minuto |  cardiologia  |      Oscar Reis      |        Clinica Sabeanas       | 80.35709844559588 | 6.636333252792683  |
# | Batimentos cardíacos por minuto |  cardiologia  |      Oscar Reis      | Clinica Joaquim Chaves Sintra | 80.25427821522308 |  7.19310615694385  |
# | Batimentos cardíacos por minuto |  cardiologia  |      Oscar Reis      |        Clinica Dentejo        | 80.07901408450705 | 6.033512081868666  |
# | Batimentos cardíacos por minuto |  cardiologia  |   Matheus Siqueira   |              None             | 79.85186900958466 | 6.784819965928498  |
# | Batimentos cardíacos por minuto |  cardiologia  |   Matheus Siqueira   |     Clinica Sorriso Famoso    | 79.74857142857144 | 7.099604473030127  |
# | Batimentos cardíacos por minuto |  cardiologia  |   Matheus Siqueira   |        Clinica Sabeanas       | 80.29811764705883 | 6.715464592419611  |
# | Batimentos cardíacos por minuto |  cardiologia  |   Matheus Siqueira   | Clinica Joaquim Chaves Sintra | 80.06992647058824 | 6.750195149283979  |
# | Batimentos cardíacos por minuto |  cardiologia  |   Matheus Siqueira   |    Centro Clinico dos Anjos   | 79.39954773869344 | 6.721494157927809  |
# | Batimentos cardíacos por minuto |  cardiologia  |    Matheus Bastos    |              None             | 80.17277495769873 | 6.9584703826420995 |
# | Batimentos cardíacos por minuto |  cardiologia  |    Matheus Bastos    |        Clinica Sabeanas       |  80.0228076923077 | 7.145159698485682  |
# | Batimentos cardíacos por minuto |  cardiologia  |    Matheus Bastos    |    Centro Clinico dos Anjos   | 80.29057401812696 | 6.8059203814384315 |
# | Batimentos cardíacos por minuto |  cardiologia  |    Marcos Urbano     |              None             | 79.68521943573676 | 6.806602653702516  |
# | Batimentos cardíacos por minuto |  cardiologia  |    Marcos Urbano     | Clinica Joaquim Chaves Sintra | 79.44205882352941 | 7.788058775249185  |
# | Batimentos cardíacos por minuto |  cardiologia  |    Marcos Urbano     |        Clinica Dentejo        | 79.18966165413532 | 6.369697195842601  |
# | Batimentos cardíacos por minuto |  cardiologia  |    Marcos Urbano     |    Centro Clinico dos Anjos   | 80.26529629629627 | 6.781540338053951  |
# | Batimentos cardíacos por minuto |  cardiologia  |    Joaquim Yanez     |              None             | 79.76119808306711 | 6.715400211625264  |
# | Batimentos cardíacos por minuto |  cardiologia  |    Joaquim Yanez     |        Clinica Sabeanas       | 79.47932584269662 | 6.528290689054282  |
# | Batimentos cardíacos por minuto |  cardiologia  |    Joaquim Yanez     | Clinica Joaquim Chaves Sintra | 80.20483146067417 | 6.260503284568171  |
# | Batimentos cardíacos por minuto |  cardiologia  |    Joaquim Yanez     |        Clinica Dentejo        | 79.37917159763317 | 7.174845970358171  |
# | Batimentos cardíacos por minuto |  cardiologia  |    Joaquim Yanez     |    Centro Clinico dos Anjos   | 79.94100358422938 | 6.610255071561029  |
# | Batimentos cardíacos por minuto |  cardiologia  |     João Zanini      |              None             | 80.42131699846861 |  6.7327681319653   |
# | Batimentos cardíacos por minuto |  cardiologia  |     João Zanini      |     Clinica Sorriso Famoso    |  80.2194071146245 | 6.961250231591079  |
# | Batimentos cardíacos por minuto |  cardiologia  |     João Zanini      |        Clinica Sabeanas       | 80.54902499999999 | 6.5809635920110505 |
# | Batimentos cardíacos por minuto |  cardiologia  |    Ingrid Furtado    |              None             | 80.09330016583748 | 6.802590928297922  |
# | Batimentos cardíacos por minuto |  cardiologia  |    Ingrid Furtado    |        Clinica Sabeanas       | 80.33500000000005 |  6.47421683454375  |
# | Batimentos cardíacos por minuto |  cardiologia  |    Ingrid Furtado    | Clinica Joaquim Chaves Sintra | 79.67607361963191 | 7.271689741738271  |
# | Batimentos cardíacos por minuto |  cardiologia  |    Ingrid Furtado    |        Clinica Dentejo        |  79.9907792207792 |  7.04486139821698  |
# | Batimentos cardíacos por minuto |  cardiologia  |    Ingrid Furtado    |    Centro Clinico dos Anjos   | 80.27238095238098 | 6.556520252628619  |
# | Batimentos cardíacos por minuto |  cardiologia  |      Igor Witt       |              None             | 80.04776872964163 | 6.199700271619154  |
# | Batimentos cardíacos por minuto |  cardiologia  |      Igor Witt       |     Clinica Sorriso Famoso    | 80.72989169675085 | 6.6918801210913355 |
# | Batimentos cardíacos por minuto |  cardiologia  |      Igor Witt       | Clinica Joaquim Chaves Sintra | 79.43683794466403 | 5.796976406364919  |
# | Batimentos cardíacos por minuto |  cardiologia  |      Igor Witt       |        Clinica Dentejo        | 79.63845238095234 | 5.407261980770378  |
# | Batimentos cardíacos por minuto |  cardiologia  |   Humberto Antunes   |              None             | 79.80199052132697 | 6.868989303187445  |
# | Batimentos cardíacos por minuto |  cardiologia  |   Humberto Antunes   |     Clinica Sorriso Famoso    | 79.49463276836158 | 7.7253948397549665 |
# | Batimentos cardíacos por minuto |  cardiologia  |   Humberto Antunes   |        Clinica Sabeanas       | 80.38378640776699 | 6.156327886147475  |
# | Batimentos cardíacos por minuto |  cardiologia  |   Humberto Antunes   |        Clinica Dentejo        |  79.3493454545455 |  6.54428180160688  |
# | Batimentos cardíacos por minuto |  cardiologia  |   Humberto Antunes   |    Centro Clinico dos Anjos   | 81.32705128205127 | 6.5363922278535656 |
# | Batimentos cardíacos por minuto |  cardiologia  | Henrique Vasconcelos |              None             | 79.73349378881983 | 6.618379598340173  |
# | Batimentos cardíacos por minuto |  cardiologia  | Henrique Vasconcelos |     Clinica Sorriso Famoso    | 79.34629213483149 |  6.57204975157136  |
# | Batimentos cardíacos por minuto |  cardiologia  | Henrique Vasconcelos |        Clinica Dentejo        |  79.565635359116  | 6.461752516987473  |
# | Batimentos cardíacos por minuto |  cardiologia  | Henrique Vasconcelos |    Centro Clinico dos Anjos   | 80.08192982456146 | 6.727019474672217  |
# | Batimentos cardíacos por minuto |  cardiologia  |   Giovanna Gouveia   |              None             | 80.28207221350074 | 6.865827474873106  |
# | Batimentos cardíacos por minuto |  cardiologia  |   Giovanna Gouveia   |        Clinica Sabeanas       | 80.21368700265252 | 6.8928582143818335 |
# | Batimentos cardíacos por minuto |  cardiologia  |   Giovanna Gouveia   |    Centro Clinico dos Anjos   | 80.38123076923077 | 6.825225836261856  |
# | Batimentos cardíacos por minuto |  cardiologia  |   Francisca Jardim   |              None             | 80.60638801261824 | 6.525958264907434  |
# | Batimentos cardíacos por minuto |  cardiologia  |   Francisca Jardim   |     Clinica Sorriso Famoso    | 80.53962389380517 |  6.6135188102276   |
# | Batimentos cardíacos por minuto |  cardiologia  |   Francisca Jardim   |        Clinica Dentejo        | 80.77219780219781 |  6.30018119435889  |
# | Batimentos cardíacos por minuto |  cardiologia  |  Fernanda Kawasaki   |              None             |  79.6643853820598 | 7.069811613483895  |
# | Batimentos cardíacos por minuto |  cardiologia  |  Fernanda Kawasaki   |     Clinica Sorriso Famoso    |     79.548375     | 7.171598399894893  |
# | Batimentos cardíacos por minuto |  cardiologia  |  Fernanda Kawasaki   |        Clinica Dentejo        |  79.7960283687943 | 6.950159177669234  |
# | Batimentos cardíacos por minuto |  cardiologia  |  Claudia Bananeira   |              None             |  80.0747633136095 | 6.545446298891455  |
# | Batimentos cardíacos por minuto |  cardiologia  |  Claudia Bananeira   |        Clinica Dentejo        | 79.78003546099289 | 6.728856325227268  |
# | Batimentos cardíacos por minuto |  cardiologia  |  Claudia Bananeira   |    Centro Clinico dos Anjos   | 80.28571065989851 | 6.402627326161006  |
# | Batimentos cardíacos por minuto |  cardiologia  |    Cátia Esteves     |              None             | 80.16998468606432 | 6.643474535573919  |
# | Batimentos cardíacos por minuto |  cardiologia  |    Cátia Esteves     |        Clinica Sabeanas       | 80.27139107611545 | 6.652394900141372  |
# | Batimentos cardíacos por minuto |  cardiologia  |    Cátia Esteves     |    Centro Clinico dos Anjos   | 80.02794117647059 | 6.628351274199855  |
# | Batimentos cardíacos por minuto |  cardiologia  |   Catarina Ortega    |              None             | 79.74457413249216 | 6.560170942872562  |
# | Batimentos cardíacos por minuto |  cardiologia  |   Catarina Ortega    |     Clinica Sorriso Famoso    |  79.4136057692308 | 6.5586647751690785 |
# | Batimentos cardíacos por minuto |  cardiologia  |   Catarina Ortega    |        Clinica Sabeanas       | 80.02466135458165 | 6.276972157576661  |
# | Batimentos cardíacos por minuto |  cardiologia  |   Catarina Ortega    | Clinica Joaquim Chaves Sintra | 79.73622857142855 | 6.930428356522992  |
# | Batimentos cardíacos por minuto |  cardiologia  |  Catarina Gonçalves  |              None             | 80.16234848484848 | 6.930908075955576  |
# | Batimentos cardíacos por minuto |  cardiologia  |  Catarina Gonçalves  | Clinica Joaquim Chaves Sintra | 79.71874100719418 | 6.818123504833815  |
# | Batimentos cardíacos por minuto |  cardiologia  |  Catarina Gonçalves  |        Clinica Dentejo        | 80.48518324607328 | 6.994180216693996  |
# | Batimentos cardíacos por minuto |  cardiologia  |    Bruna Botelho     |              None             | 79.86257812499994 | 6.720746615668639  |
# | Batimentos cardíacos por minuto |  cardiologia  |    Bruna Botelho     |     Clinica Sorriso Famoso    | 79.44525773195876 | 6.474714513116212  |
# | Batimentos cardíacos por minuto |  cardiologia  |    Bruna Botelho     | Clinica Joaquim Chaves Sintra | 80.26457286432164 |  6.8447693922904   |
# | Batimentos cardíacos por minuto |  cardiologia  |    Bruna Botelho     |        Clinica Dentejo        |  79.7477034883721 | 6.704835482988478  |
# | Batimentos cardíacos por minuto | clínica geral |         None         |              None             | 79.96904022301902 | 6.685052945347084  |
# | Batimentos cardíacos por minuto | clínica geral |    Xuxa Carvalho     |              None             | 79.82685294117637 | 6.251836255581954  |
# | Batimentos cardíacos por minuto | clínica geral |    Xuxa Carvalho     |        Clinica Sabeanas       | 79.36270270270266 | 6.246680523306994  |
# | Batimentos cardíacos por minuto | clínica geral |    Xuxa Carvalho     |        Clinica Dentejo        | 80.00032323232325 | 6.244912458369019  |
# +---------------------------------+---------------+----------------------+-------------------------------+-------------------+--------------------+
# Truncated to displaylimit of 100.

# %% [markdown]
# ## 6. Índices

# %% [markdown]
# Apresente as instruções SQL para criação de índices para melhorar os tempos de cada uma das consultas listadas abaixo sobre a base de dados ‘Saude’. Justifique a sua escolha de tabela(s), atributo(s) e tipo(s) de índice, explicando que operações seriam otimizadas e como. Considere que não existam índices nas tabelas, além daqueles implícitos ao declarar chaves primárias e estrangeiras, e para efeitos deste exercício, suponha que o tamanho das tabelas excede a memória disponível em várias ordens de magnitude.

# %% [markdown]
# ### 6.1
# Queremos otimizar a seguinte query: (modificada para aumentar a seletividade de acordo com os dados populados)

# %%
# %%sql
# -- O Postgres estava a subestimar a seletividade do filtro
# -- >= do valor e a fazer más decisões devido a isso
# -- (A começar com um seqscan na consulta em vez de filtar observacao);
# -- Logo foi necessário desativar os sequencial scans
# -- Para analizar as opções diferentes de índices
# SET enable_seqscan = FALSE;
#
# -- Atualizar as estatísticas para o query planner
# VACUUM ANALYZE;
#
# EXPLAIN (ANALYZE, BUFFERS)
# SELECT
#   paciente.nome
# FROM
#   paciente
#   JOIN consulta USING (ssn)
#   JOIN observacao USING (id)
# WHERE
#   -- ~0,03% de seletividade
#   parametro = 'Pressão arterial diastólica'
#   AND valor >= 110;
# Out:
# 23 rows affected.
# +------------------------------------------------------------------------------------------------------------------------------------------------------+
# |                                                                      QUERY PLAN                                                                      |
# +------------------------------------------------------------------------------------------------------------------------------------------------------+
# |                           Hash Join  (cost=266.63..2976.92 rows=1023 width=15) (actual time=1.094..1.463 rows=216 loops=1)                           |
# |                                                        Hash Cond: (consulta.ssn = paciente.ssn)                                                      |
# |                                                                Buffers: shared hit=687                                                               |
# |                          ->  Nested Loop  (cost=0.84..2708.45 rows=1023 width=12) (actual time=0.019..0.351 rows=216 loops=1)                        |
# |                                                                   Buffers: shared hit=655                                                            |
# |              ->  Index Only Scan using idx_obs on observacao  (cost=0.42..52.89 rows=1023 width=4) (actual time=0.013..0.034 rows=216 loops=1)       |
# |                               Index Cond: ((parametro = 'Pressão arterial diastólica'::text) AND (valor >= '110'::double precision))                 |
# |                                                                          Heap Fetches: 0                                                             |
# |                                                                       Buffers: shared hit=6                                                          |
# |            ->  Index Only Scan using idx_consulta_sns on consulta  (cost=0.42..2.60 rows=1 width=16) (actual time=0.001..0.001 rows=1 loops=216)     |
# |                                                                  Index Cond: (id = observacao.id)                                                    |
# |                                                                          Heap Fetches: 0                                                             |
# |                                                                      Buffers: shared hit=649                                                         |
# |                            ->  Hash  (cost=203.28..203.28 rows=5000 width=27) (actual time=1.064..1.065 rows=5000 loops=1)                           |
# |                                                        Buckets: 8192  Batches: 1  Memory Usage: 353kB                                                |
# |                                                                    Buffers: shared hit=32                                                            |
# |         ->  Index Only Scan using idx_paciente_nome on paciente  (cost=0.28..203.28 rows=5000 width=27) (actual time=0.005..0.401 rows=5000 loops=1) |
# |                                                                          Heap Fetches: 0                                                             |
# |                                                                       Buffers: shared hit=32                                                         |
# |                                                                      Planning:                                                                       |
# |                                                                 Buffers: shared hit=54                                                               |
# |                                                               Planning Time: 0.456 ms                                                                |
# |                                                               Execution Time: 1.492 ms                                                               |
# +------------------------------------------------------------------------------------------------------------------------------------------------------+

# %%
# %%sql
# DROP INDEX IF EXISTS idx_obs;
#
# CREATE INDEX idx_obs ON observacao USING BTREE (parametro, valor, id);
#
# DROP INDEX IF EXISTS idx_consulta_sns;
#
# CREATE INDEX idx_consulta_sns ON consulta USING BTREE (id, ssn);
#
# DROP INDEX IF EXISTS idx_paciente_nome;
#
# CREATE INDEX idx_paciente_nome ON paciente USING BTREE (ssn, nome);
# Out:
# ++
# ||
# ++
# ++

# %% [markdown]
# ### Justificação
#
# Sendo que o que queremos filtrar, está na tabela "observacao", é mais prático começar por aí. Queremos um "parametro" = a um certo valor e um "valor" >= a um certo valor.
#
# Uma maneira eficiente para seletividades baixas é com a utilização de um indíce para "observacao" com ("parametro", "valor") como chaves compostas, sendo BTREE a melhor opção, pois queremos uma range de "valor".
#
# Isto deveria resultar num Bitmap Index Scan para filtrar o "parametro" e "valor", mas depois teremos de voltar à tabela para obter o "id" da consulta, com um Bitmap Heap Scan.
#
# Mas podemos fazer melhor - Se usarmos um covering index e incluirmos o id no índice, podemos fazer na "observacao" apenas um Index Only Scan!
#
# Depois temos o "id" que já é chave primária de "consulta", e queremos da "consulta" o "ssn", que é chave primária de "paciente" de qual queremos o "nome".
#
# Isto resulta em dois Index Scans em "consulta" e depois em "paciente".
# Podemos também optar por evitar acessos à heap de todo, com dois índices novos de chaves compostas ("id", "ssn") em "consulta" e ("ssn", "nome") (B-Tree pois Hash não suporta chaves compostas), isto substitui os Index Scans por Index Only Scans mas o ganho começa a ser bastante menos notório, especialmente em relação ao primeiro índice, e tem um custo não negligenciável na memória, então é preciso considerar se vale a pena.

# %% [markdown]
# ### 6.2
# Queremos otimizar a seguinte query: (modificada para aumentar a seletividade de acordo com os dados populados)

# %%
# %%sql
# -- O Postgres estava a subestimar a seletividade do filtro
# -- BETWEEN da data e a fazer más decisões devido a isso
# -- (A começar com parallel seqscans em receita em vez de filtar consulta);
# -- Logo foi necessário desativar os sequencial scans
# -- Para analizar as opções diferentes de índices
# SET
#   enable_seqscan = TRUE;
#
# -- Atualizar as estatísticas para o query planner se necessário
# VACUUM ANALYZE;
#
# EXPLAIN ANALYZE
# SELECT
#   especialidade,
#   SUM(quantidade) AS qtd
# FROM
#   medico
#   JOIN consulta USING (nif)
#   JOIN receita USING (codigo_sns)
# WHERE
#   -- ~1% de seletividade
#   data BETWEEN '2023-01-01' AND '2023-01-07'
# GROUP BY
#   especialidade
# ORDER BY
#   qtd;
# Out:
# 20 rows affected.
# +-----------------------------------------------------------------------------------------------------------------------------------------------------------------+
# |                                                                            QUERY PLAN                                                                           |
# +-----------------------------------------------------------------------------------------------------------------------------------------------------------------+
# |                                     Sort  (cost=4299.03..4299.05 rows=6 width=20) (actual time=3.753..3.755 rows=6 loops=1)                                     |
# |                                                                Sort Key: (sum(receita.quantidade))                                                              |
# |                                                                Sort Method: quicksort  Memory: 25kB                                                             |
# |                                ->  HashAggregate  (cost=4298.89..4298.95 rows=6 width=20) (actual time=3.748..3.750 rows=6 loops=1)                             |
# |                                                                     Group Key: medico.especialidade                                                             |
# |                                                                      Batches: 1  Memory Usage: 24kB                                                             |
# |                                  ->  Nested Loop  (cost=3.19..4280.42 rows=3695 width=14) (actual time=0.033..3.329 rows=4183 loops=1)                          |
# |                                       ->  Hash Join  (cost=2.77..70.58 rows=1318 width=25) (actual time=0.027..0.286 rows=1496 loops=1)                         |
# |                                                                        Hash Cond: (consulta.nif = medico.nif)                                                   |
# |                     ->  Index Only Scan using idx_consulta_data on consulta  (cost=0.42..64.53 rows=1318 width=23) (actual time=0.008..0.106 rows=1496 loops=1) |
# |                                                        Index Cond: ((data >= '2023-01-01'::date) AND (data <= '2023-01-07'::date))                              |
# |                                                                                      Heap Fetches: 0                                                            |
# |                                               ->  Hash  (cost=1.60..1.60 rows=60 width=22) (actual time=0.016..0.016 rows=60 loops=1)                           |
# |                                                                       Buckets: 1024  Batches: 1  Memory Usage: 12kB                                             |
# |                                           ->  Seq Scan on medico  (cost=0.00..1.60 rows=60 width=22) (actual time=0.004..0.008 rows=60 loops=1)                 |
# |                        ->  Index Only Scan using idx_receita on receita  (cost=0.42..3.15 rows=4 width=15) (actual time=0.002..0.002 rows=3 loops=1496)         |
# |                                                                    Index Cond: (codigo_sns = consulta.codigo_sns)                                               |
# |                                                                                   Heap Fetches: 0                                                               |
# |                                                                     Planning Time: 0.318 ms                                                                     |
# |                                                                     Execution Time: 3.784 ms                                                                    |
# +-----------------------------------------------------------------------------------------------------------------------------------------------------------------+

# %%
# %%sql
# DROP INDEX IF EXISTS idx_consulta_data;
#
# CREATE INDEX idx_consulta_data ON consulta USING BTREE (data, codigo_sns, nif);
#
# DROP INDEX IF EXISTS idx_medico_especialidade;
#
# CREATE INDEX idx_medico_especialidade ON medico USING BTREE (nif, especialidade);
#
# DROP INDEX IF EXISTS idx_receita;
#
# CREATE INDEX idx_receita ON receita USING BTREE (codigo_sns, quantidade);
# Out:
# ++
# ||
# ++
# ++

# %% [markdown]
# ### Justificação
#
# Sendo que o que queremos filtrar, está na tabela "consulta", é mais prático começar por aí. Queremos consultas com a "data" dentro de uma range entre duas datas, e também queremos o \"codigo_sns" para a "receita" e "nif" para o "medico", logo, pelas mesmas razões do 6.1 é proveitoso uma chave composta ("data", "codigo_sns", "nif") para obter um Index Only Scan, B-Tree é indicado para esta situação.
#
# Semelhantemente ao 6.1, agora precisamos da "quantidade" de "receita" e "especialidade" de "medico", e com o último índice o query planner está a efetuar Index Scans mas podemos passar a Index Only Scans com mais alguns índices de chave composta, que seriam em "receita" (codigo_sns, quantidade), e em "medico" ("nif", "especialidade"), e foi escolhido B-Tree pois Hash não suporta chaves compostas.
