# %% [markdown]
# # Projeto de Bases de Dados - Parte 2
#
# ### Docente Responsável
#
# Prof. FirstName Teste
#
# ### Grupo GG
# <dl>
#     <dt>11 horas (33.3%)</dt>
#     <dd>ist1107030 Gabriel dos Reis Fonseca Castelo Ferreira</dd>
#     <dt>11 horas (33.3%)</dt>
#     <dd>ist1106763 David Rocha Rodrigues</dd>
#     <dt>1 horas (33.3%)</dt>
#     <dd>ist1105882 Duarte Mendonça Gouveia</dd>
# <dl>

# %%
# %reload_ext sql
# %config SqlMagic.displaycon = 0
# %config SqlMagic.displaylimit = 100
# %sql postgresql+psycopg://postgres:postgres@postgres/postgres
# Out:
# There's a new jupysql version available (0.10.10), you're running 0.10.9. To upgrade: pip install jupysql --upgrade
# Deploy Streamlit apps for free on Ploomber Cloud! Learn more: https://ploomber.io/s/signup
# Connecting to 'postgresql+psycopg://postgres:***@postgres/postgres'

# %% [markdown]
# ## 0. Carregamento da Base de Dados
#
# Crie a base de dados “Saude” no PostgreSQL e execute os comandos para criação das tabelas desta base de dados apresentados de seguida

# %%
# %%sql
# DROP TABLE IF EXISTS clinica CASCADE;
# DROP TABLE IF EXISTS enfermeiro CASCADE;
# DROP TABLE IF EXISTS medico CASCADE;
# DROP TABLE IF EXISTS trabalha CASCADE;
# DROP TABLE IF EXISTS paciente CASCADE;
# DROP TABLE IF EXISTS receita CASCADE;
# DROP TABLE IF EXISTS consulta CASCADE;
# DROP TABLE IF EXISTS observacao CASCADE;
#
# CREATE TABLE clinica(
# 	nome VARCHAR(80) PRIMARY KEY,
# 	telefone VARCHAR(15) UNIQUE NOT NULL CHECK (telefone ~ '^[0-9]+$'),
# 	morada VARCHAR(255) UNIQUE NOT NULL
# );
#
# CREATE TABLE enfermeiro(
# 	nif CHAR(9) PRIMARY KEY CHECK (nif ~ '^[0-9]+$'),
# 	nome VARCHAR(80) UNIQUE NOT NULL,
# 	telefone VARCHAR(15) NOT NULL CHECK (telefone ~ '^[0-9]+$'),
# 	morada VARCHAR(255) NOT NULL,
# 	nome_clinica VARCHAR(80) NOT NULL REFERENCES clinica (nome)
# );
#
# CREATE TABLE medico(
# 	nif CHAR(9) PRIMARY KEY CHECK (nif ~ '^[0-9]+$'),
# 	nome VARCHAR(80) UNIQUE NOT NULL,
# 	telefone VARCHAR(15) NOT NULL CHECK (telefone ~ '^[0-9]+$'),
# 	morada VARCHAR(255) NOT NULL,
# 	especialidade VARCHAR(80) NOT NULL
# );
#
# CREATE TABLE trabalha(
# nif CHAR(9) NOT NULL REFERENCES medico,
# nome VARCHAR(80) NOT NULL REFERENCES clinica,
# dia_da_semana SMALLINT,
# PRIMARY KEY (nif, dia_da_semana)
# );
#
# CREATE TABLE paciente(
# 	ssn CHAR(11) PRIMARY KEY CHECK (ssn ~ '^[0-9]+$'),
# nif CHAR(9) UNIQUE NOT NULL CHECK (nif ~ '^[0-9]+$'),
# 	nome VARCHAR(80) NOT NULL,
# 	telefone VARCHAR(15) NOT NULL CHECK (telefone ~ '^[0-9]+$'),
# 	morada VARCHAR(255) NOT NULL,
# 	data_nasc DATE NOT NULL
# );
#
# CREATE TABLE consulta(
# 	id SERIAL PRIMARY KEY,
# 	ssn CHAR(11) NOT NULL REFERENCES paciente,
# 	nif CHAR(9) NOT NULL REFERENCES medico,
# 	nome VARCHAR(80) NOT NULL REFERENCES clinica,
# 	data DATE NOT NULL,
# 	hora TIME NOT NULL,
# 	codigo_sns CHAR(12) UNIQUE CHECK (codigo_sns ~ '^[0-9]+$'),
# 	UNIQUE(ssn, data, hora),
# 	UNIQUE(nif, data, hora)
# );
#
# CREATE TABLE receita(
# 	codigo_sns CHAR(12) NOT NULL REFERENCES consulta (codigo_sns),
# 	medicamento VARCHAR(155) NOT NULL,
# 	quantidade SMALLINT NOT NULL CHECK (quantidade > 0),
# 	PRIMARY KEY (codigo_sns, medicamento)
# );
#
# CREATE TABLE observacao(
# 	id INTEGER NOT NULL REFERENCES consulta,
# 	parametro VARCHAR(155) NOT NULL,
# 	valor FLOAT,
# PRIMARY KEY (id, parametro)
# );
#
# -- For some reason the docker container is defaulting to Universal Time,
# -- to avoid confusion we will change to Portuguese time
# SET timezone TO 'Europe/Lisbon';
# Out:
# ++
# ||
# ++
# ++

# %% [markdown]
# ## 1. Restrições de Integridade
#
# Apresente o código para implementar as seguintes restrições de integridade, se necessário, com recurso a extensões procedimentais SQL (Stored Procedures e Triggers):

# %% [markdown]
# (RI-1) Os horários das consultas são à hora exata ou meia-hora no horário 8-13h e 14-19h

# %%
# %%sql
# ALTER TABLE consulta
# DROP CONSTRAINT IF EXISTS consulta_time_check;
#
# ALTER TABLE consulta ADD CONSTRAINT consulta_time_check CHECK (
#   (
#     (
#       EXTRACT(
#         HOUR
#         FROM
#           hora
#       ) BETWEEN 8 AND 12
#     )
#     OR (
#       EXTRACT(
#         HOUR
#         FROM
#           hora
#       ) BETWEEN 14 AND 18
#     )
#     AND EXTRACT(
#       MINUTE
#       FROM
#         hora
#     ) IN (0, 30)
#   )
# );
# Out:
# ++
# ||
# ++
# ++

# %% [markdown]
# (RI-2) Um médico não se pode consultar a si próprio, embora possa ser paciente de outros médicos no sistema

# %%
# %%sql
# CREATE OR REPLACE FUNCTION consulta_medico() RETURNS TRIGGER AS $$
#     BEGIN
#         IF EXISTS (
#             SELECT * FROM paciente p
#             WHERE NEW.ssn = p.ssn AND NEW.nif = p.nif
#         ) THEN
#             RAISE EXCEPTION 'Um médico não se pode consultar a si próprio,';
#         END IF;
#         RETURN NEW;
#     END;
# $$ LANGUAGE plpgsql;
# CREATE OR REPLACE TRIGGER consulta_medico_trigger BEFORE INSERT ON consulta
#     FOR EACH ROW EXECUTE FUNCTION consulta_medico();
# Out:
# ++
# ||
# ++
# ++

# %% [markdown]
# (RI-3) Um médico só pode dar consultas na clínica em que trabalha no dia da semana correspondente à data da consulta

# %%
# %%sql
# CREATE OR REPLACE FUNCTION consulta_clinica() RETURNS TRIGGER AS $$
#     BEGIN
#         IF NOT EXISTS (
#             SELECT * FROM trabalha t
#             WHERE NEW.nif = t.nif AND NEW.nome = t.nome AND EXTRACT(ISODOW FROM NEW.data) = t.dia_da_semana
#         ) THEN
#             RAISE EXCEPTION 'Um médico só pode dar consultas na clínica em que trabalha no dia da semana correspondente à data da consulta';
#         END IF;
#         RETURN NEW;
#     END;
# $$ LANGUAGE plpgsql;
# CREATE OR REPLACE TRIGGER consulta_clinica_trigger BEFORE INSERT ON consulta
#     FOR EACH ROW EXECUTE FUNCTION consulta_clinica();
# Out:
# ++
# ||
# ++
# ++

# %% [markdown]
# ## 2. Preenchimento da Base de Dados
#
# Preencha todas as tabelas da base de dados de forma consistente (após execução do ponto anterior) com os seguintes requisitos adicionais de cobertura:
# - 5 clínicas, de pelo menos 3 localidades diferentes do distrito de Lisboa
# - 5-6 enfermeiros por clínica
# - 20 médicos de especialidade ‘clínica geral’ e 40 outros distribuídos como entender por até 5 outras especialidades médicas (incluindo pelo menos, ‘ortopedia’ e ‘cardiologia’). Cada médico deve trabalhar em pelo menos duas clínicas, e em cada clínica a cada dia da semana (incluindo fins de semana), devem estar pelo menos 8 médicos
# - Cerca de 5.000 pacientes
# - Um número mínimo de consultas em 2023 e 2024 tais que cada paciente tem pelo menos uma consulta, e em cada dia há pelo menos 20 consultas por clínica, e pelo menos 2 consultas por médico
# - ~80% das consultas tem receita médica associada, e as receitas têm 1 a 6 medicamentos em quantidades entre 1 e 3
# - Todas as consultas têm 1 a 5 observações de sintomas (com parâmetro mas sem valor) e 0 a 3 observações métricas (com parâmetro e valor). Deve haver ~50 parâmetros diferentes para os sintomas (sem valor) e ~20 parâmetros diferentes para as observações métricas (com valor) e os dois conjuntos devem ser disjuntos.
# - Todas as moradas são nacionais e seguem o formato Português, terminando com código postal: XXXX-XXX e de seguida a localidade.
# Deve ainda garantir que todas as consultas necessárias para a realização dos pontos seguintes do projeto produzem um resultado não vazio.
#
# O código para preenchimento da base de dados deve ser compilado num ficheiro "populate.sql", anexado ao relatório, que contém com comandos INSERT ou alternativamente comandos COPY que populam as tabelas a partir de ficheiros de texto, também eles anexados ao relatório.

# %% [markdown]
# Para preencher a base de dados correr o comando no psql
# ```bash
# psql -h postgres -U postgres
# \i ~/data/populate.sql
# ```

# %% [markdown]
# ## 3. Desenvolvimento de Aplicação
#
# Crie um protótipo de RESTful web service para gestão de consultas por acesso programático à base de dados ‘Saude’ através de uma API que devolve respostas em JSON, implementando os seguintes endpoints REST:
#
# |Endpoint|Descrição|
# |--------|---------|
# |/|Lista todas as clínicas (nome e morada).|
# |/c/\<clinica>/|Lista todas as especialidades oferecidas na \<clinica>.|
# |/c/\<clinica>/\<especialidade>/|Lista todos os médicos (nome) da \<especialidade> que trabalham na <clínica> e os primeiros três horários disponíveis para consulta de cada um deles (data e hora).|
# |/a/\<clinica>/registar/|Registra uma marcação de consulta na \<clinica> na base de dados (populando a respectiva tabela). Recebe como argumentos um paciente, um médico, e uma data e hora (posteriores ao momento de agendamento).|
# |/a/\<clinica>/cancelar/|Cancela uma marcação de consulta que ainda não se realizou na \<clinica> (o seu horário é posterior ao momento do cancelamento), removendo a entrada da respectiva tabela na base de dados. Recebe como argumentos um paciente, um médico, e uma data e hora.|

# %% [markdown]
# ### Explicação da arquitetura da aplicação web, incluindo a descrição dos vários ficheiros na pasta app/arquivos e a relação entre eles
#
# ...

# %% [markdown]
# ## 4. Vistas
#
# Crie uma vista materializada que detalhe as informações mais importantes sobre as consultas dos pacientes, combinando a informação de várias tabelas da base de dados. A vista deve ter o seguinte esquema:
#
# ### *historial_paciente(id, ssn, nif, nome, data, ano, mes, dia_do_mes, localidade, especialidade, tipo, chave, valor)*
#
# em que:
# - *id, ssn, nif, nome* e *data*: correspondem ao atributos homónimos da tabela **consulta**
# - *ano, mes, dia_do_mes* e *dia_da_semana*: são derivados do atributo *data* da tabela **consulta**
# - *localidade*: é derivado do atributo *morada* da tabela **clinica**
# - *especialidade*: corresponde ao atributo homónimo da tabela **medico**
# - *tipo*: toma os valores ‘observacao’ ou ‘receita’ consoante o preenchimento dos campos seguintes
# - *chave*: corresponde ao atributo *parametro* da tabela **observacao** ou ao atributo *medicamento* da tabela **receita**
# - *valor*: corresponde ao atributo *valor* da tabela **observacao** ou ao atributo *quantidade* da tabela **receita**

# %%
# %%sql
# -- CREATE MATERIALIZED VIEW ...
# DROP MATERIALIZED VIEW IF EXISTS historial_paciente;
# CREATE MATERIALIZED VIEW historial_paciente AS
# SELECT
#     consulta.id,
#     consulta.ssn, consulta.nif,
#     consulta.nome AS nome_consulta,
#     EXTRACT(YEAR FROM consulta.data) AS ano,
#     EXTRACT(MONTH FROM consulta.data) AS mes,
#     EXTRACT(DAY FROM consulta.data) AS dia_do_mes,
#     medico.especialidade,
#     regexp_replace(clinica.morada, '.*\d{4}-\d{3} ', '') AS localidade,
#     'observacao' AS tipo,
#     observacao.parametro AS chave,
#     observacao.valor AS valor
# FROM consulta
# JOIN medico  ON consulta.nif = medico.nif
# JOIN clinica ON consulta.nome = clinica.nome
# LEFT JOIN observacao ON consulta.id = observacao.id
# UNION
# SELECT
#     consulta.id,
#     consulta.ssn,
#     consulta.nif,
#     consulta.nome AS nome_consulta,
#     EXTRACT(YEAR FROM consulta.data) AS ano,
#     EXTRACT(MONTH FROM consulta.data) AS mes,
#     EXTRACT(DAY FROM consulta.data) AS dia_do_mes,
#     medico.especialidade,
#     regexp_replace(clinica.morada, '.*\d{4}-\d{3} ', '') AS localidade,
#     'receita' AS tipo,
#     receita.medicamento AS chave,
#     receita.quantidade AS valor
# FROM
#     consulta
# JOIN
#     medico ON consulta.nif = medico.nif
# JOIN
#     clinica ON consulta.nome = clinica.nome
# LEFT JOIN
#     receita ON consulta.codigo_sns = receita.codigo_sns;
# Out:
# 1153223 rows affected.
# ++
# ||
# ++
# ++

# %% [markdown]
# ## 5. Análise de Dados (SQL e OLAP)
#
# Usando a vista desenvolvida no ponto anterior, complementada com outras tabelas da base de dados ‘Saude’ quando necessário, apresente a consulta SQL mais sucinta para cada um dos seguintes objetivos analíticos. Pode usar as instruções ROLLUP, CUBE, GROUPING SETS ou as cláusulas UNION of GROUP BY para os objetivos em que lhe parecer adequado.

# %% [markdown]
# 1. Determinar que paciente(s) tiveram menos progresso no tratamento das suas doenças do foro ortopédico para atribuição de uma consulta gratuita. Considera-se que o indicador de falta de progresso é o intervalo temporal máximo entre duas observações do mesmo sintoma (i.e. registos de tipo ‘observacao’ com a mesma chave e com valor NULL) em consultas de ortopedia.

# %%
# %%sql
# -- SELECT ...
# SELECT h.ssn, h.chave, (MAX(h.data) - MIN(h.data)) as
# FROM historial_paciente h
# WHERE h.tipo = 'observacao' AND ISNULL(h.valor)
# Out:
# 1153223 rows affected.
# +----+-------------+-----------+--------------------------+------+-----+------------+---------------+------------+------------+--------------------------------------------------+---------+
# | id |     ssn     |    nif    |      nome_consulta       | ano  | mes | dia_do_mes | especialidade | localidade |    tipo    |                      chave                       |  valor  |
# +----+-------------+-----------+--------------------------+------+-----+------------+---------------+------------+------------+--------------------------------------------------+---------+
# | 0  | 11066100748 | 200105044 | Centro Clinico dos Anjos | 2023 |  1  |     1      | clínica geral |   Lisboa   | observacao |             Dificuldade para engolir             |   None  |
# | 0  | 11066100748 | 200105044 | Centro Clinico dos Anjos | 2023 |  1  |     1      | clínica geral |   Lisboa   | observacao |        Nível de cálcio no sangue (mg/dL)         |   9.56  |
# | 0  | 11066100748 | 200105044 | Centro Clinico dos Anjos | 2023 |  1  |     1      | clínica geral |   Lisboa   | observacao |      Nível de creatinina no sangue (mg/dL)       |   1.12  |
# | 0  | 11066100748 | 200105044 | Centro Clinico dos Anjos | 2023 |  1  |     1      | clínica geral |   Lisboa   | observacao |                   Olhos secos                    |   None  |
# | 0  | 11066100748 | 200105044 | Centro Clinico dos Anjos | 2023 |  1  |     1      | clínica geral |   Lisboa   | observacao |                 Perda de olfato                  |   None  |
# | 0  | 11066100748 | 200105044 | Centro Clinico dos Anjos | 2023 |  1  |     1      | clínica geral |   Lisboa   | observacao |              Triglicerídeos (mg/dL)              |  119.02 |
# | 0  | 11066100748 | 200105044 | Centro Clinico dos Anjos | 2023 |  1  |     1      | clínica geral |   Lisboa   |  receita   |                 Benzoylecgonine                  |   2.0   |
# | 0  | 11066100748 | 200105044 | Centro Clinico dos Anjos | 2023 |  1  |     1      | clínica geral |   Lisboa   |  receita   |                    Mescaline                     |   3.0   |
# | 0  | 11066100748 | 200105044 | Centro Clinico dos Anjos | 2023 |  1  |     1      | clínica geral |   Lisboa   |  receita   |                  Nicomorphine                    |   1.0   |
# | 1  | 11181634905 | 200105044 | Centro Clinico dos Anjos | 2023 |  1  |     1      | clínica geral |   Lisboa   | observacao |                    Calafrios                     |   None  |
# | 1  | 11181634905 | 200105044 | Centro Clinico dos Anjos | 2023 |  1  |     1      | clínica geral |   Lisboa   | observacao |         Nível de sódio no sangue (mEq/L)         |  138.35 |
# | 1  | 11181634905 | 200105044 | Centro Clinico dos Anjos | 2023 |  1  |     1      | clínica geral |   Lisboa   |  receita   |                    Fonazepam                     |   3.0   |
# | 1  | 11181634905 | 200105044 | Centro Clinico dos Anjos | 2023 |  1  |     1      | clínica geral |   Lisboa   |  receita   |                    Mefenorex                     |   3.0   |
# | 1  | 11181634905 | 200105044 | Centro Clinico dos Anjos | 2023 |  1  |     1      | clínica geral |   Lisboa   |  receita   |                   Normorphine                    |   2.0   |
# | 2  | 11468322875 | 200105044 | Centro Clinico dos Anjos | 2023 |  1  |     1      | clínica geral |   Lisboa   | observacao |                   Constipação                    |   None  |
# | 2  | 11468322875 | 200105044 | Centro Clinico dos Anjos | 2023 |  1  |     1      | clínica geral |   Lisboa   | observacao |                     Diarreia                     |   None  |
# | 2  | 11468322875 | 200105044 | Centro Clinico dos Anjos | 2023 |  1  |     1      | clínica geral |   Lisboa   | observacao |                  Dor nas pernas                  |   None  |
# | 2  | 11468322875 | 200105044 | Centro Clinico dos Anjos | 2023 |  1  |     1      | clínica geral |   Lisboa   | observacao |                 Erupção cutânea                  |   None  |
# | 2  | 11468322875 | 200105044 | Centro Clinico dos Anjos | 2023 |  1  |     1      | clínica geral |   Lisboa   | observacao |                   Olhos secos                    |   None  |
# | 2  | 11468322875 | 200105044 | Centro Clinico dos Anjos | 2023 |  1  |     1      | clínica geral |   Lisboa   |  receita   |                 Dihydromorphine                  |   2.0   |
# | 2  | 11468322875 | 200105044 | Centro Clinico dos Anjos | 2023 |  1  |     1      | clínica geral |   Lisboa   |  receita   |                  Flubromazolam                   |   1.0   |
# | 3  | 11943453279 | 200159365 | Centro Clinico dos Anjos | 2023 |  1  |     1      | clínica geral |   Lisboa   | observacao |                     Diarreia                     |   None  |
# | 3  | 11943453279 | 200159365 | Centro Clinico dos Anjos | 2023 |  1  |     1      | clínica geral |   Lisboa   | observacao | Frequência respiratória (respirações por minuto) |  16.33  |
# | 3  | 11943453279 | 200159365 | Centro Clinico dos Anjos | 2023 |  1  |     1      | clínica geral |   Lisboa   | observacao |                     Insônia                      |   None  |
# | 3  | 11943453279 | 200159365 | Centro Clinico dos Anjos | 2023 |  1  |     1      | clínica geral |   Lisboa   | observacao |                    Rouquidão                     |   None  |
# | 3  | 11943453279 | 200159365 | Centro Clinico dos Anjos | 2023 |  1  |     1      | clínica geral |   Lisboa   |  receita   |                  Buprenorphine                   |   3.0   |
# | 3  | 11943453279 | 200159365 | Centro Clinico dos Anjos | 2023 |  1  |     1      | clínica geral |   Lisboa   |  receita   |                  Heptobarbital                   |   3.0   |
# | 3  | 11943453279 | 200159365 | Centro Clinico dos Anjos | 2023 |  1  |     1      | clínica geral |   Lisboa   |  receita   |                Methylamphetamine                 |   2.0   |
# | 4  | 10284129622 | 200159365 | Centro Clinico dos Anjos | 2023 |  1  |     1      | clínica geral |   Lisboa   | observacao |                     Confusão                     |   None  |
# | 4  | 10284129622 | 200159365 | Centro Clinico dos Anjos | 2023 |  1  |     1      | clínica geral |   Lisboa   | observacao |                 Dores musculares                 |   None  |
# | 4  | 10284129622 | 200159365 | Centro Clinico dos Anjos | 2023 |  1  |     1      | clínica geral |   Lisboa   | observacao |                      Febre                       |   None  |
# | 4  | 10284129622 | 200159365 | Centro Clinico dos Anjos | 2023 |  1  |     1      | clínica geral |   Lisboa   | observacao |                 Nariz escorrendo                 |   None  |
# | 4  | 10284129622 | 200159365 | Centro Clinico dos Anjos | 2023 |  1  |     1      | clínica geral |   Lisboa   | observacao |                   pH sanguíneo                   |   7.4   |
# | 4  | 10284129622 | 200159365 | Centro Clinico dos Anjos | 2023 |  1  |     1      | clínica geral |   Lisboa   |  receita   |                       None                       |   None  |
# | 5  | 12437774840 | 200159365 | Centro Clinico dos Anjos | 2023 |  1  |     1      | clínica geral |   Lisboa   | observacao |         Batimentos cardíacos por minuto          |  73.62  |
# | 5  | 12437774840 | 200159365 | Centro Clinico dos Anjos | 2023 |  1  |     1      | clínica geral |   Lisboa   | observacao |                  Ganho de peso                   |   None  |
# | 5  | 12437774840 | 200159365 | Centro Clinico dos Anjos | 2023 |  1  |     1      | clínica geral |   Lisboa   | observacao |                   Olhos secos                    |   None  |
# | 5  | 12437774840 | 200159365 | Centro Clinico dos Anjos | 2023 |  1  |     1      | clínica geral |   Lisboa   |  receita   |                    Dipipanone                    |   3.0   |
# | 5  | 12437774840 | 200159365 | Centro Clinico dos Anjos | 2023 |  1  |     1      | clínica geral |   Lisboa   |  receita   |                    Myrophine                     |   2.0   |
# | 6  | 12117209936 | 200159365 | Centro Clinico dos Anjos | 2023 |  1  |     1      | clínica geral |   Lisboa   | observacao |                  Dor de cabeça                   |   None  |
# | 6  | 12117209936 | 200159365 | Centro Clinico dos Anjos | 2023 |  1  |     1      | clínica geral |   Lisboa   | observacao |          Índice de massa corporal (IMC)          |  22.76  |
# | 6  | 12117209936 | 200159365 | Centro Clinico dos Anjos | 2023 |  1  |     1      | clínica geral |   Lisboa   | observacao |        Nível de cálcio no sangue (mg/dL)         |   9.49  |
# | 6  | 12117209936 | 200159365 | Centro Clinico dos Anjos | 2023 |  1  |     1      | clínica geral |   Lisboa   | observacao |                   Palpitações                    |   None  |
# | 6  | 12117209936 | 200159365 | Centro Clinico dos Anjos | 2023 |  1  |     1      | clínica geral |   Lisboa   | observacao |               Zumbido nos ouvidos                |   None  |
# | 6  | 12117209936 | 200159365 | Centro Clinico dos Anjos | 2023 |  1  |     1      | clínica geral |   Lisboa   |  receita   |                   Carfentanyl                    |   3.0   |
# | 6  | 12117209936 | 200159365 | Centro Clinico dos Anjos | 2023 |  1  |     1      | clínica geral |   Lisboa   |  receita   |                   Drostanolone                   |   3.0   |
# | 6  | 12117209936 | 200159365 | Centro Clinico dos Anjos | 2023 |  1  |     1      | clínica geral |   Lisboa   |  receita   |                  Flubromazepam                   |   1.0   |
# | 6  | 12117209936 | 200159365 | Centro Clinico dos Anjos | 2023 |  1  |     1      | clínica geral |   Lisboa   |  receita   |                  Flunitrazepam                   |   1.0   |
# | 6  | 12117209936 | 200159365 | Centro Clinico dos Anjos | 2023 |  1  |     1      | clínica geral |   Lisboa   |  receita   |                  Trimeperidine                   |   1.0   |
# | 7  | 11708236550 | 200216426 | Centro Clinico dos Anjos | 2023 |  1  |     1      | clínica geral |   Lisboa   | observacao |                    Calafrios                     |   None  |
# | 7  | 11708236550 | 200216426 | Centro Clinico dos Anjos | 2023 |  1  |     1      | clínica geral |   Lisboa   | observacao |                 Congestão nasal                  |   None  |
# | 7  | 11708236550 | 200216426 | Centro Clinico dos Anjos | 2023 |  1  |     1      | clínica geral |   Lisboa   | observacao |                     Insônia                      |   None  |
# | 7  | 11708236550 | 200216426 | Centro Clinico dos Anjos | 2023 |  1  |     1      | clínica geral |   Lisboa   |  receita   |                       None                       |   None  |
# | 8  | 10272506282 | 200216426 | Centro Clinico dos Anjos | 2023 |  1  |     1      | clínica geral |   Lisboa   | observacao |             Dificuldade para engolir             |   None  |
# | 8  | 10272506282 | 200216426 | Centro Clinico dos Anjos | 2023 |  1  |     1      | clínica geral |   Lisboa   | observacao |                     Sudorese                     |   None  |
# | 8  | 10272506282 | 200216426 | Centro Clinico dos Anjos | 2023 |  1  |     1      | clínica geral |   Lisboa   | observacao |              Triglicerídeos (mg/dL)              |  119.65 |
# | 8  | 10272506282 | 200216426 | Centro Clinico dos Anjos | 2023 |  1  |     1      | clínica geral |   Lisboa   |  receita   |                 Chlordiazepoxide                 |   3.0   |
# | 8  | 10272506282 | 200216426 | Centro Clinico dos Anjos | 2023 |  1  |     1      | clínica geral |   Lisboa   |  receita   |                  Cocaethylene                    |   1.0   |
# | 8  | 10272506282 | 200216426 | Centro Clinico dos Anjos | 2023 |  1  |     1      | clínica geral |   Lisboa   |  receita   |              Propylbenzoylecgonine               |   1.0   |
# | 9  | 10227928853 | 200216426 | Centro Clinico dos Anjos | 2023 |  1  |     1      | clínica geral |   Lisboa   | observacao |                    Ansiedade                     |   None  |
# | 9  | 10227928853 | 200216426 | Centro Clinico dos Anjos | 2023 |  1  |     1      | clínica geral |   Lisboa   | observacao |                   Dor de dente                   |   None  |
# | 9  | 10227928853 | 200216426 | Centro Clinico dos Anjos | 2023 |  1  |     1      | clínica geral |   Lisboa   | observacao |        Nível de glicose no sangue (mg/dL)        |  107.33 |
# | 9  | 10227928853 | 200216426 | Centro Clinico dos Anjos | 2023 |  1  |     1      | clínica geral |   Lisboa   | observacao |                    Rouquidão                     |   None  |
# | 9  | 10227928853 | 200216426 | Centro Clinico dos Anjos | 2023 |  1  |     1      | clínica geral |   Lisboa   | observacao |            Saturação de oxigênio (%)             |  98.13  |
# | 9  | 10227928853 | 200216426 | Centro Clinico dos Anjos | 2023 |  1  |     1      | clínica geral |   Lisboa   | observacao |                     Sudorese                     |   None  |
# | 9  | 10227928853 | 200216426 | Centro Clinico dos Anjos | 2023 |  1  |     1      | clínica geral |   Lisboa   |  receita   |                   Bufotenine                     |   3.0   |
# | 10 | 10663770797 | 200216426 | Centro Clinico dos Anjos | 2023 |  1  |     1      | clínica geral |   Lisboa   | observacao |                      Febre                       |   None  |
# | 10 | 10663770797 | 200216426 | Centro Clinico dos Anjos | 2023 |  1  |     1      | clínica geral |   Lisboa   | observacao |                 Olhos vermelhos                  |   None  |
# | 10 | 10663770797 | 200216426 | Centro Clinico dos Anjos | 2023 |  1  |     1      | clínica geral |   Lisboa   | observacao |            Pressão arterial sistólica            |  118.62 |
# | 10 | 10663770797 | 200216426 | Centro Clinico dos Anjos | 2023 |  1  |     1      | clínica geral |   Lisboa   | observacao |                      Vômito                      |   None  |
# | 10 | 10663770797 | 200216426 | Centro Clinico dos Anjos | 2023 |  1  |     1      | clínica geral |   Lisboa   |  receita   |                       None                       |   None  |
# | 11 | 11300797032 | 200314227 | Centro Clinico dos Anjos | 2023 |  1  |     1      | clínica geral |   Lisboa   | observacao |             Colesterol total (mg/dL)             |  162.42 |
# | 11 | 11300797032 | 200314227 | Centro Clinico dos Anjos | 2023 |  1  |     1      | clínica geral |   Lisboa   | observacao |                   Dor no peito                   |   None  |
# | 11 | 11300797032 | 200314227 | Centro Clinico dos Anjos | 2023 |  1  |     1      | clínica geral |   Lisboa   | observacao |                      Febre                       |   None  |
# | 11 | 11300797032 | 200314227 | Centro Clinico dos Anjos | 2023 |  1  |     1      | clínica geral |   Lisboa   | observacao |          Índice de massa corporal (IMC)          |  21.23  |
# | 11 | 11300797032 | 200314227 | Centro Clinico dos Anjos | 2023 |  1  |     1      | clínica geral |   Lisboa   | observacao |                  Perda de peso                   |   None  |
# | 11 | 11300797032 | 200314227 | Centro Clinico dos Anjos | 2023 |  1  |     1      | clínica geral |   Lisboa   | observacao |           Volume urinário (mL por dia)           | 1249.83 |
# | 11 | 11300797032 | 200314227 | Centro Clinico dos Anjos | 2023 |  1  |     1      | clínica geral |   Lisboa   |  receita   |                   Benzethidine                   |   2.0   |
# | 11 | 11300797032 | 200314227 | Centro Clinico dos Anjos | 2023 |  1  |     1      | clínica geral |   Lisboa   |  receita   |                    Methadone                     |   3.0   |
# | 12 | 10497400310 | 200314227 | Centro Clinico dos Anjos | 2023 |  1  |     1      | clínica geral |   Lisboa   | observacao |                Dores articulares                 |   None  |
# | 12 | 10497400310 | 200314227 | Centro Clinico dos Anjos | 2023 |  1  |     1      | clínica geral |   Lisboa   | observacao |                Hemoglobina (g/dL)                |   15.2  |
# | 12 | 10497400310 | 200314227 | Centro Clinico dos Anjos | 2023 |  1  |     1      | clínica geral |   Lisboa   | observacao |                     Insônia                      |   None  |
# | 12 | 10497400310 | 200314227 | Centro Clinico dos Anjos | 2023 |  1  |     1      | clínica geral |   Lisboa   | observacao |        Nível de cálcio no sangue (mg/dL)         |   9.69  |
# | 12 | 10497400310 | 200314227 | Centro Clinico dos Anjos | 2023 |  1  |     1      | clínica geral |   Lisboa   | observacao |        Nível de glicose no sangue (mg/dL)        |  111.55 |
# | 12 | 10497400310 | 200314227 | Centro Clinico dos Anjos | 2023 |  1  |     1      | clínica geral |   Lisboa   | observacao |                   Olhos secos                    |   None  |
# | 12 | 10497400310 | 200314227 | Centro Clinico dos Anjos | 2023 |  1  |     1      | clínica geral |   Lisboa   |  receita   |                       None                       |   None  |
# | 13 | 11141955606 | 200314227 | Centro Clinico dos Anjos | 2023 |  1  |     1      | clínica geral |   Lisboa   | observacao |         Batimentos cardíacos por minuto          |  84.12  |
# | 13 | 11141955606 | 200314227 | Centro Clinico dos Anjos | 2023 |  1  |     1      | clínica geral |   Lisboa   | observacao |                    Depressão                     |   None  |
# | 13 | 11141955606 | 200314227 | Centro Clinico dos Anjos | 2023 |  1  |     1      | clínica geral |   Lisboa   | observacao |                  Dor nas pernas                  |   None  |
# | 13 | 11141955606 | 200314227 | Centro Clinico dos Anjos | 2023 |  1  |     1      | clínica geral |   Lisboa   | observacao |                  Lacrimejamento                  |   None  |
# | 13 | 11141955606 | 200314227 | Centro Clinico dos Anjos | 2023 |  1  |     1      | clínica geral |   Lisboa   | observacao |            Temperatura corporal (°C)             |   36.7  |
# | 13 | 11141955606 | 200314227 | Centro Clinico dos Anjos | 2023 |  1  |     1      | clínica geral |   Lisboa   | observacao |           Volume urinário (mL por dia)           |  1817.3 |
# | 13 | 11141955606 | 200314227 | Centro Clinico dos Anjos | 2023 |  1  |     1      | clínica geral |   Lisboa   |  receita   |                    Stanozolol                    |   2.0   |
# | 14 | 11852076818 | 200508120 | Centro Clinico dos Anjos | 2023 |  1  |     1      |  cardiologia  |   Lisboa   | observacao |                     Arrepios                     |   None  |
# | 14 | 11852076818 | 200508120 | Centro Clinico dos Anjos | 2023 |  1  |     1      |  cardiologia  |   Lisboa   | observacao |                 Nariz escorrendo                 |   None  |
# | 14 | 11852076818 | 200508120 | Centro Clinico dos Anjos | 2023 |  1  |     1      |  cardiologia  |   Lisboa   | observacao |        Nível de cálcio no sangue (mg/dL)         |   10.3  |
# | 14 | 11852076818 | 200508120 | Centro Clinico dos Anjos | 2023 |  1  |     1      |  cardiologia  |   Lisboa   | observacao |       Número de plaquetas (milhões por mL)       |  318.54 |
# | 14 | 11852076818 | 200508120 | Centro Clinico dos Anjos | 2023 |  1  |     1      |  cardiologia  |   Lisboa   | observacao |                      Tosse                       |   None  |
# | 14 | 11852076818 | 200508120 | Centro Clinico dos Anjos | 2023 |  1  |     1      |  cardiologia  |   Lisboa   |  receita   |                       None                       |   None  |
# | 15 | 11291137385 | 200508120 | Centro Clinico dos Anjos | 2023 |  1  |     1      |  cardiologia  |   Lisboa   | observacao |             Colesterol total (mg/dL)             |  173.74 |
# +----+-------------+-----------+--------------------------+------+-----+------------+---------------+------------+------------+--------------------------------------------------+---------+
# Truncated to displaylimit of 100.

# %% [markdown]
# 2. Determinar que medicamentos estão a ser usados para tratar doenças crónicas do foro cardiológico. Considera-se que qualificam quaisquer medicamentos receitados ao mesmo paciente (qualquer que ele seja) pelo menos uma vez por mês durante pelo menos doze meses consecutivos, em consultas de cardiologia.

# %%
# %%sql
# -- SELECT ...

# %% [markdown]
# 3. Explorar as quantidades totais receitadas de cada medicamento em 2023, globalmente, e com drill down nas dimensões espaço (localidade > clinica), tempo (mes > dia_do_mes), e médico  (especialidade > nome \[do médico]), separadamente.

# %%
# %%sql
# -- SELECT ...

# %% [markdown]
# 4. Determinar se há enviesamento na medição de algum parâmetros entre clínicas, especialidades médicas ou médicos, sendo para isso necessário listar o valor médio e desvio padrão de todos os parâmetros de observações métricas (i.e. com valor não NULL) com drill down na dimensão médico (globalmente > especialidade > nome \[do médico]) e drill down adicional (sobre o anterior) por clínica.

# %%
# %%sql
# -- SELECT ...

# %% [markdown]
# ## 6. Índices

# %% [markdown]
# Apresente as instruções SQL para criação de índices para melhorar os tempos de cada uma das consultas listadas abaixo sobre a base de dados ‘Saude’. Justifique a sua escolha de tabela(s), atributo(s) e tipo(s) de índice, explicando que operações seriam otimizadas e como. Considere que não existam índices nas tabelas, além daqueles implícitos ao declarar chaves primárias e estrangeiras, e para efeitos deste exercício, suponha que o tamanho das tabelas excede a memória disponível em várias ordens de magnitude.

# %% [markdown]
# ### 6.1
# Queremos otimizar a seguinte query: (modificada para aumentar a seletividade de acordo com os dados populados)

# %%
# %%sql
# -- O Postgres estava a subestimar a seletividade do filtro
# -- >= do valor e a fazer más decisões devido a isso
# -- (A começar com um seqscan na consulta em vez de filtar observacao);
# -- Logo foi necessário desativar os sequencial scans
# -- Para analizar as opções diferentes de índices
# SET
#   enable_seqscan = FALSE;
#
# -- Atualizar as estatísticas para o query planner
# VACUUM ANALYZE;
#
# EXPLAIN (ANALYZE, BUFFERS)
# SELECT
#   paciente.nome
# FROM
#   paciente
#   JOIN consulta USING (ssn)
#   JOIN observacao USING (id)
# WHERE
#   -- ~1% de seletividade
#   parametro = 'Pressão arterial diastólica'
#   AND valor >= 100;
# Out:
# 23 rows affected.
# +------------------------------------------------------------------------------------------------------------------------------------------------------+
# |                                                                      QUERY PLAN                                                                      |
# +------------------------------------------------------------------------------------------------------------------------------------------------------+
# |                          Hash Join  (cost=266.63..3174.11 rows=1156 width=15) (actual time=0.958..2.887 rows=1505 loops=1)                           |
# |                                                        Hash Cond: (consulta.ssn = paciente.ssn)                                                      |
# |                                                                Buffers: shared hit=4564                                                              |
# |                         ->  Nested Loop  (cost=0.84..2905.30 rows=1156 width=12) (actual time=0.013..1.709 rows=1505 loops=1)                        |
# |                                                                   Buffers: shared hit=4532                                                           |
# |              ->  Index Only Scan using idx_obs on observacao  (cost=0.42..55.55 rows=1156 width=4) (actual time=0.010..0.130 rows=1505 loops=1)      |
# |                               Index Cond: ((parametro = 'Pressão arterial diastólica'::text) AND (valor >= '100'::double precision))                 |
# |                                                                          Heap Fetches: 0                                                             |
# |                                                                       Buffers: shared hit=16                                                         |
# |            ->  Index Only Scan using idx_consulta_sns on consulta  (cost=0.42..2.47 rows=1 width=16) (actual time=0.001..0.001 rows=1 loops=1505)    |
# |                                                                  Index Cond: (id = observacao.id)                                                    |
# |                                                                          Heap Fetches: 0                                                             |
# |                                                                      Buffers: shared hit=4516                                                        |
# |                            ->  Hash  (cost=203.28..203.28 rows=5000 width=27) (actual time=0.938..0.938 rows=5000 loops=1)                           |
# |                                                        Buckets: 8192  Batches: 1  Memory Usage: 353kB                                                |
# |                                                                    Buffers: shared hit=32                                                            |
# |         ->  Index Only Scan using idx_paciente_nome on paciente  (cost=0.28..203.28 rows=5000 width=27) (actual time=0.003..0.318 rows=5000 loops=1) |
# |                                                                          Heap Fetches: 0                                                             |
# |                                                                       Buffers: shared hit=32                                                         |
# |                                                                      Planning:                                                                       |
# |                                                                 Buffers: shared hit=51                                                               |
# |                                                               Planning Time: 0.245 ms                                                                |
# |                                                               Execution Time: 2.931 ms                                                               |
# +------------------------------------------------------------------------------------------------------------------------------------------------------+

# %%
# %%sql
# DROP INDEX IF EXISTS idx_obs;
#
# CREATE INDEX idx_obs ON observacao USING BTREE (parametro, valor, id);
#
# DROP INDEX IF EXISTS idx_consulta_sns;
#
# CREATE INDEX idx_consulta_sns ON consulta USING BTREE (id, ssn);
#
# DROP INDEX IF EXISTS idx_paciente_nome;
#
# CREATE INDEX idx_paciente_nome ON paciente USING BTREE (ssn, nome);
# Out:
# ++
# ||
# ++
# ++

# %% [markdown]
# ### Justificação
#
# Sendo que o que queremos filtrar, está na tabela "observacao", é mais prático começar por aí. Queremos um "parametro" = a um certo valor e um "valor" >= a um certo valor.
#
# Uma maneira eficiente para seletividades baixas é com a utilização de um indíce para "observacao" com ("parametro", "valor") como chaves compostas, sendo BTREE a melhor opção, pois queremos uma range de "valor".
#
# Isto deveria resultar num Bitmap Index Scan para filtrar o "parametro" e "valor", mas depois teremos de voltar à tabela para obter o "id" da consulta, com um Bitmap Heap Scan.
#
# Mas podemos fazer melhor - Se usarmos um covering index e incluirmos o id no índice, podemos fazer na "observacao" apenas um Index Only Scan!
#
# Depois temos o "id" que já é chave primária de "consulta", e queremos da "consulta" o "ssn", que é chave primária de "paciente" de qual queremos o "nome".
#
# Isto resulta em dois Index Scans em "consulta" e depois em "paciente".
# Podemos também optar por evitar acessos à heap de todo, com dois índices novos de chaves compostas ("id", "ssn") em "consulta" e ("ssn", "nome") (B-Tree pois Hash não suporta chaves compostas), isto substitui os Index Scans por Index Only Scans mas o ganho começa a ser bastante menos notório, especialmente em relação ao primeiro índice, e tem um custo não negligenciável na memória, então é preciso considerar se vale a pena.

# %% [markdown]
# ### 6.2
# Queremos otimizar a seguinte query: (modificada para aumentar a seletividade de acordo com os dados populados)

# %%
# %%sql
# -- O Postgres estava a subestimar a seletividade do filtro
# -- BETWEEN da data e a fazer más decisões devido a isso
# -- (A começar com parallel seqscans em receita em vez de filtar consulta);
# -- Logo foi necessário desativar os sequencial scans
# -- Para analizar as opções diferentes de índices
# SET
#   enable_seqscan = FALSE;
#
# -- Atualizar as estatísticas para o query planner se necessário
# VACUUM ANALYZE;
#
# EXPLAIN ANALYZE
# SELECT
#   especialidade,
#   SUM(quantidade) AS qtd
# FROM
#   medico
#   JOIN consulta USING (nif)
#   JOIN receita USING (codigo_sns)
# WHERE
#   -- ~1% de seletividade
#   data BETWEEN '2023-01-01' AND '2023-01-07'
# GROUP BY
#   especialidade
# ORDER BY
#   qtd;
# Out:
# 21 rows affected.
# +-----------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# |                                                                               QUERY PLAN                                                                              |
# +-----------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# |                                        Sort  (cost=4308.14..4308.16 rows=6 width=20) (actual time=3.444..3.447 rows=6 loops=1)                                        |
# |                                                                   Sort Key: (sum(receita.quantidade))                                                                 |
# |                                                                   Sort Method: quicksort  Memory: 25kB                                                                |
# |                                   ->  HashAggregate  (cost=4308.01..4308.07 rows=6 width=20) (actual time=3.432..3.435 rows=6 loops=1)                                |
# |                                                                        Group Key: medico.especialidade                                                                |
# |                                                                         Batches: 1  Memory Usage: 24kB                                                                |
# |                                     ->  Nested Loop  (cost=10.63..4289.44 rows=3713 width=14) (actual time=0.029..3.020 rows=4138 loops=1)                            |
# |                                          ->  Hash Join  (cost=10.21..72.41 rows=1324 width=25) (actual time=0.025..0.348 rows=1478 loops=1)                           |
# |                                                                           Hash Cond: (consulta.nif = medico.nif)                                                      |
# |                        ->  Index Only Scan using idx_consulta_data on consulta  (cost=0.42..58.90 rows=1324 width=23) (actual time=0.007..0.162 rows=1478 loops=1)    |
# |                                                           Index Cond: ((data >= '2023-01-01'::date) AND (data <= '2023-01-07'::date))                                 |
# |                                                                                         Heap Fetches: 0                                                               |
# |                                                  ->  Hash  (cost=9.04..9.04 rows=60 width=22) (actual time=0.015..0.016 rows=60 loops=1)                              |
# |                                                                          Buckets: 1024  Batches: 1  Memory Usage: 12kB                                                |
# |                           ->  Index Only Scan using idx_medico_especialidade on medico  (cost=0.14..9.04 rows=60 width=22) (actual time=0.003..0.006 rows=60 loops=1) |
# |                                                                                            Heap Fetches: 0                                                            |
# |                           ->  Index Only Scan using idx_receita on receita  (cost=0.42..3.15 rows=4 width=15) (actual time=0.001..0.002 rows=3 loops=1478)            |
# |                                                                       Index Cond: (codigo_sns = consulta.codigo_sns)                                                  |
# |                                                                                      Heap Fetches: 0                                                                  |
# |                                                                        Planning Time: 3.051 ms                                                                        |
# |                                                                        Execution Time: 3.478 ms                                                                       |
# +-----------------------------------------------------------------------------------------------------------------------------------------------------------------------+

# %%
# %%sql
# DROP INDEX IF EXISTS idx_consulta_data;
#
# CREATE INDEX idx_consulta_data ON consulta USING BTREE (data, codigo_sns, nif);
#
# DROP INDEX IF EXISTS idx_medico_especialidade;
#
# CREATE INDEX idx_medico_especialidade ON medico USING BTREE (nif, especialidade);
#
# DROP INDEX IF EXISTS idx_receita;
#
# CREATE INDEX idx_receita ON receita USING BTREE (codigo_sns, quantidade);
# Out:
# ++
# ||
# ++
# ++

# %% [markdown]
# ### Justificação
#
# Sendo que o que queremos filtrar, está na tabela "consulta", é mais prático começar por aí. Queremos consultas com a "data" dentro de uma range entre duas datas, e também queremos o \"codigo_sns" para a "receita" e "nif" para o "medico", logo, pelas mesmas razões do 6.1 é proveitoso uma chave composta ("data", "codigo_sns", "nif") para obter um Index Only Scan, B-Tree é indicado para esta situação.
#
# Semelhantemente ao 6.1, agora precisamos da "quantidade" de "receita" e "especialidade" de "medico", e com o último índice o query planner está a efetuar Index Scans mas podemos passar a Index Only Scans com mais alguns índices de chave composta, que seriam em "receita" (codigo_sns, quantidade), e em "medico" ("nif", "especialidade"), e foi escolhido B-Tree pois Hash não suporta chaves compostas.
